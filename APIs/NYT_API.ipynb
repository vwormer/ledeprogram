# %% [markdown]
# # Working with the The New York Times' APIs
#
# http://developer.nytimes.com

# %%
import urllib2
import json

# %% [markdown]
# # 1. What books topped the NYT best-sellers list on your birthday in 2009?

# %%
url_books = "http://api.nytimes.com/svc/books/v3/lists/2009-09-26/hardcover-fiction.json?&api-key=ce80414991af0079fab0d883bee2b9c0:17:72421670"

# %%
url_books
# Out:
# 'http://api.nytimes.com/svc/books/v3/lists/2009-09-26/hardcover-fiction.json?&api-key=ce80414991af0079fab0d883bee2b9c0:17:72421670'

# %%
response = urllib2.urlopen(url_books)
contents = response.read()

# %%
data = json.loads(contents)
data.keys()
# Out:
# [u'status', u'last_modified', u'num_results', u'results', u'copyright']

# %%
bestseller_list = data['results']['books']
titles = [book['title'] for book in bestseller_list]
titles
# Out:
# [u'THE LAST SONG',
#  u'SOUTH OF BROAD',
#  u'THE HELP',
#  u'ALEX CROSS\u2019S \u2018TRIAL\u2019',
#  u'SPARTAN GOLD',
#  u'DARK SLAYER',
#  u'THE WHITE QUEEN',
#  u'DEXTER BY DESIGN',
#  u'THE GIRL WHO PLAYED WITH FIRE',
#  u'DEAD AND GONE',
#  u'A GATE AT THE STAIRS',
#  u'206 BONES',
#  u'HOMER & LANGLEY',
#  u'THE ELEVENTH VICTIM',
#  u'THAT OLD CAPE MAGIC',
#  u'THE GOLDEN CITY',
#  u'THE HOST',
#  u'THE SPIRE',
#  u'DAY AFTER NIGHT',
#  u'EVEN MONEY']

# %% [markdown]
# # 2. Muammar Gaddafi's name can be transliterated many many ways. There are a million and one versions used for his last name - Gadafi, Gaddafi, Kadafi, and Qaddafi to name a few. How many times has the New York Times referred to him by each of those names?

# %%
api_key = "6df4165384263aabcda090938bd2872c:8:72421670"

# %%
url_gadafi = "http://api.nytimes.com/svc/search/v2/articlesearch.json?q=Gadafi+Libya&api-key=ffaf60d7d82258e112dd4fb2b5e4e2d6:3:72421680"

# %%
response = urllib2.urlopen(url_gadafi)
contents = response.read()

# %%
data = json.loads(contents)
data['response']['meta']['hits']
# Out:
# 0

# %%
url_gaddafi = "http://api.nytimes.com/svc/search/v2/articlesearch.json?q=Gaddafi+Libya&api-key=ffaf60d7d82258e112dd4fb2b5e4e2d6:3:72421680"

# %%
response = urllib2.urlopen(url_gaddafi)
contents = response.read()
data = json.loads(contents)
data['response']['meta']['hits']
# Out:
# 798

# %%
url_kadafi = "http://api.nytimes.com/svc/search/v2/articlesearch.json?q=Kadafi+Libya&api-key=ffaf60d7d82258e112dd4fb2b5e4e2d6:3:72421680"

# %%
response = urllib2.urlopen(url_kadafi)
contents = response.read()
data = json.loads(contents)
data['response']['meta']['hits']
# Out:
# 4

# %%
url_qaddafi = "http://api.nytimes.com/svc/search/v2/articlesearch.json?q=Qaddafi+Libya&api-key=ffaf60d7d82258e112dd4fb2b5e4e2d6:3:72421680"

# %%
response = urllib2.urlopen(url_qaddafi)
contents = response.read()
data = json.loads(contents)
data['response']['meta']['hits']
# Out:
# 5644

# %% [markdown]
# # 3. What's the title of the first story to mention the word 'hipster' in 1995? What's the first paragraph?

# %%
url_hipster ="http://api.nytimes.com/svc/search/v2/articlesearch.json?q=hipster&begin_date=19950101&end_date=19951231&sort=oldest&api-key=ffaf60d7d82258e112dd4fb2b5e4e2d6:3:72421680"

# %%
response = urllib2.urlopen(url_hipster)
contents = response.read()
data = json.loads(contents)

# %%
print data['response']['docs'][0]['lead_paragraph']
# Out:
# Portable record players with built-in speakers, from the 1960's, are the latest points on hipster score cards. In some cases, they are the only way to listen to many of the old LP or 45-r.p.m. recordings still around but not released on cassette or CD. Usually available in white plastic or metal, they can be found in flea markets and secondhand stores. One style has the arm cast in the shape of a cobra. (Don Hogan Charles/The New York Times)

# %% [markdown]
# # 4. How many times was gay marriage mentioned in the NYT between 1950-1959, 1960-1969, 1970-1978, 1980-1989, 1990-2099, 2000-2009, and 2010-present?
#
# Tip: You'll want to put quotes around the search term so it isn't just looking for "gay" and "marriage" in the same article.
#
# Tip: Write code to find the number of mentions between Jan 1, 1950 and Dec 31, 1959. Turn that code into a function that takes two parameters, a start date and an end date, and returns the number of mentions.

# %%
url_gay_all = "http://api.nytimes.com/svc/search/v2/articlesearch.json?q=%22gay+marriage%22&begin_date=19500101&end_date=20150702&api-key=ffaf60d7d82258e112dd4fb2b5e4e2d6:3:72421680"

# %%
response = urllib2.urlopen(url_gay)
contents = response.read()
data = json.loads(contents)
data["response"]
# Out:
# {u'docs': [], u'meta': {u'hits': 0, u'offset': 0, u'time': 55}}

# %%
def go_gay(begin_date,end_date):
   url = "http://api.nytimes.com/svc/search/v2/articlesearch.json?q="+"gay+marriage"+"&begin_date="+str(begin_date)+"&end_date="+str(end_date)+"&sort=oldest&api-key=ffaf60d7d82258e112dd4fb2b5e4e2d6:3:72421680"
   response = urllib2.urlopen(url)
   contents = response.read()
   data = json.loads(contents)
   return data['response']['meta']['hits']
print go_gay(19950101,19951231)
# Out:
# 79

# %%
time_list = [{'begin_date': 19500101,'end_date': 19591231}, {'begin_date': 19600101,'end_date': 19691231}, {"begin_date":19700101,"end_date":19781231},{"begin_date":19800101,"end_date":19891231 },{ "begin_date":19900101,"end_date":20991231 },{ "begin_date":20000101,"end_date":20091231}, {'begin_date':20100101, 'end_date' : 20151231}]

for time in time_list :
   print go_gay(time['begin_date'], time['end_date'])
# Out:
# 556
# 485
# 408
# 368
# 13228
# 4870
# 7248

# %%
data['response']['meta']['hits']
# Out:
# 0

# %%
url_gay_all = "http://api.nytimes.com/svc/search/v2/articlesearch.json?q=%22gay+marriage%22&begin_date=19500101&end_date=20150702&api-key=ffaf60d7d82258e112dd4fb2b5e4e2d6:3:72421680"

# %%
response = urllib2.urlopen(url_gay_all)
contents = response.read()
data = json.loads(contents)

# %%
data.keys()
# Out:
# [u'status', u'response', u'copyright']

# %%
name = data['response']
name["docs"]
# Out:
# [{u'_id': u'558d7a8c38f0d8123efd2bf0',
#   u'abstract': u"Op-Ed article by Prof Timothy Stewart-Winter worries that advances made for gay rights, such as ability to serve in military and Supreme Court's affirmation of right to marry, may blind people to struggles of other marginalized groups and civil rights issues; calls on gay community to devote itself to cause of protecting those on margins of society from discrimination.",
#   u'blog': [],
#   u'byline': {u'original': u'By TIMOTHY STEWART-WINTER',
#    u'person': [{u'firstname': u'Timothy',
#      u'lastname': u'STEWART-WINTER',
#      u'organization': u'',
#      u'rank': 1,
#      u'role': u'reported'}]},
#   u'document_type': u'article',
#   u'headline': {u'content_kicker': u'Opinion',
#    u'kicker': u'Opinion',
#    u'main': u'The Price of Gay Marriage',
#    u'print_headline': u'The Price of Gay Marriage'},
#   u'keywords': [{u'is_major': u'Y',
#     u'name': u'subject',
#     u'rank': u'1',
#     u'value': u'Same-Sex Marriage, Civil Unions and Domestic Partnerships'},
#    {u'is_major': u'Y',
#     u'name': u'subject',
#     u'rank': u'2',
#     u'value': u'Discrimination'},
#    {u'is_major': u'Y',
#     u'name': u'organizations',
#     u'rank': u'3',
#     u'value': u'Supreme Court (US)'},
#    {u'is_major': u'N',
#     u'name': u'subject',
#     u'rank': u'4',
#     u'value': u'Civil Rights and Liberties'},
#    {u'is_major': u'N',
#     u'name': u'subject',
#     u'rank': u'5',
#     u'value': u'Homosexuality and Bisexuality'}],
#   u'lead_paragraph': u'Will the victory at the Supreme Court blind us to our history of life in the margins?',
#   u'multimedia': [{u'height': 126,
#     u'legacy': {u'wide': u'images/2015/06/28/opinion/sunday/28GAY/28GAY-thumbWide-v2.jpg',
#      u'wideheight': u'126',
#      u'widewidth': u'190'},
#     u'subtype': u'wide',
#     u'type': u'image',
#     u'url': u'images/2015/06/28/opinion/sunday/28GAY/28GAY-thumbWide-v2.jpg',
#     u'width': 190},
#    {u'height': 840,
#     u'legacy': {u'xlarge': u'images/2015/06/28/opinion/sunday/28GAY/28gay-articleLarge.jpg',
#      u'xlargeheight': u'840',
#      u'xlargewidth': u'600'},
#     u'subtype': u'xlarge',
#     u'type': u'image',
#     u'url': u'images/2015/06/28/opinion/sunday/28GAY/28gay-articleLarge.jpg',
#     u'width': 600},
#    {u'height': 75,
#     u'legacy': {u'thumbnail': u'images/2015/06/28/opinion/sunday/28GAY/28GAY-thumbStandard-v2.jpg',
#      u'thumbnailheight': u'75',
#      u'thumbnailwidth': u'75'},
#     u'subtype': u'thumbnail',
#     u'type': u'image',
#     u'url': u'images/2015/06/28/opinion/sunday/28GAY/28GAY-thumbStandard-v2.jpg',
#     u'width': 75}],
#   u'news_desk': u'OpEd',
#   u'print_page': u'1',
#   u'pub_date': u'2015-06-28T00:00:00Z',
#   u'section_name': u'Opinion',
#   u'snippet': u'Will the victory at the Supreme Court blind us to our history of life in the margins?',
#   u'source': u'The New York Times',
#   u'subsection_name': u'Sunday Review',
#   u'type_of_material': u'Op-Ed',
#   u'web_url': u'http://www.nytimes.com/2015/06/28/opinion/sunday/the-price-of-gay-marriage.html',
#   u'word_count': u'1541'},
#  {u'_id': u'558dd5f438f0d8123efd2d2d',
#   u'abstract': None,
#   u'blog': [],
#   u'byline': {u'original': u'By EMILY BAZELON',
#    u'person': [{u'firstname': u'Emily',
#      u'lastname': u'BAZELON',
#      u'organization': u'',
#      u'rank': 1,
#      u'role': u'reported'}]},
#   u'document_type': u'article',
#   u'headline': {u'main': u'Was This the Right Way to Legalize Gay Marriage?'},
#   u'keywords': [{u'is_major': u'N',
#     u'name': u'subject',
#     u'rank': u'1',
#     u'value': u'Decisions and Verdicts'},
#    {u'is_major': u'N',
#     u'name': u'subject',
#     u'rank': u'2',
#     u'value': u'Same-Sex Marriage, Civil Unions and Domestic Partnerships'},
#    {u'is_major': u'N',
#     u'name': u'organizations',
#     u'rank': u'3',
#     u'value': u'Supreme Court (US)'},
#    {u'is_major': u'N',
#     u'name': u'persons',
#     u'rank': u'4',
#     u'value': u'Kennedy, Anthony M'},
#    {u'is_major': u'N',
#     u'name': u'persons',
#     u'rank': u'5',
#     u'value': u'Roberts, John G Jr'}],
#   u'lead_paragraph': u'The Supreme Court\u2019s dissenters raise a reasonable point about today\u2019s historic decision.',
#   u'multimedia': [{u'height': 126,
#     u'legacy': {u'wide': u'images/2015/06/26/magazine/26mag-scotus-1/26mag-scotus-1-thumbWide.jpg',
#      u'wideheight': u'126',
#      u'widewidth': u'190'},
#     u'subtype': u'wide',
#     u'type': u'image',
#     u'url': u'images/2015/06/26/magazine/26mag-scotus-1/26mag-scotus-1-thumbWide.jpg',
#     u'width': 190},
#    {u'height': 421,
#     u'legacy': {u'xlarge': u'images/2015/06/26/magazine/26mag-scotus-1/26mag-scotus-1-articleLarge.jpg',
#      u'xlargeheight': u'421',
#      u'xlargewidth': u'600'},
#     u'subtype': u'xlarge',
#     u'type': u'image',
#     u'url': u'images/2015/06/26/magazine/26mag-scotus-1/26mag-scotus-1-articleLarge.jpg',
#     u'width': 600},
#    {u'height': 75,
#     u'legacy': {u'thumbnail': u'images/2015/06/26/magazine/26mag-scotus-1/26mag-scotus-1-thumbStandard.jpg',
#      u'thumbnailheight': u'75',
#      u'thumbnailwidth': u'75'},
#     u'subtype': u'thumbnail',
#     u'type': u'image',
#     u'url': u'images/2015/06/26/magazine/26mag-scotus-1/26mag-scotus-1-thumbStandard.jpg',
#     u'width': 75}],
#   u'news_desk': u'Magazine',
#   u'print_page': None,
#   u'pub_date': u'2015-06-26T00:00:00Z',
#   u'section_name': u'Magazine',
#   u'snippet': u'The Supreme Court\u2019s dissenters raise a reasonable point about today\u2019s historic decision.',
#   u'source': u'The New York Times',
#   u'subsection_name': None,
#   u'type_of_material': u'News',
#   u'web_url': u'http://www.nytimes.com/2015/06/26/magazine/was-this-the-right-way-to-legalize-gay-marriage.html',
#   u'word_count': u'1069'},
#  {u'_id': u'5402567e38f0d80cceb1facd',
#   u'abstract': u'Transcript of panel discussion at New York Times in which New York Sen James Alesi describes why he voted in favor of gay marriage in 2001, but against it when legislation first came up in 2009.',
#   u'blog': [],
#   u'byline': [],
#   u'document_type': u'article',
#   u'headline': {u'content_kicker': u'Transcript | Gay Marriage',
#    u'kicker': u'Transcript | Gay Marriage',
#    u'main': u'Why State Senator Alesi, Supporter of Gay Marriage, Voted \u2018No\u2019 in \u201909',
#    u'print_headline': u'Why a Supporter Voted \u2018No\u2019 in \u201909',
#    u'seo': u'Why State Senator James Alesi, Supporter of Gay Marriage, Voted \u2018No\u2019 in \u201909'},
#   u'keywords': [{u'is_major': u'Y',
#     u'name': u'subject',
#     u'rank': u'1',
#     u'value': u'Same-Sex Marriage, Civil Unions and Domestic Partnerships'},
#    {u'is_major': u'N',
#     u'name': u'subject',
#     u'rank': u'2',
#     u'value': u'Politics and Government'},
#    {u'is_major': u'N',
#     u'name': u'glocations',
#     u'rank': u'3',
#     u'value': u'New York City'},
#    {u'is_major': u'Y',
#     u'name': u'persons',
#     u'rank': u'4',
#     u'value': u'Alesi, James S'},
#    {u'is_major': u'Y',
#     u'name': u'glocations',
#     u'rank': u'5',
#     u'value': u'New York State'}],
#   u'lead_paragraph': u'State Senator James Alesi, in a panel discussion, said that political considerations had led him to vote \u201cno\u201d two years ago on a bill to legalize same-sex marriage in New York.',
#   u'multimedia': [{u'height': 75,
#     u'legacy': {u'thumbnail': u'images/2011/10/23/nyregion/23MARRIAGE/23MARRIAGE-thumbStandard.jpg',
#      u'thumbnailheight': u'75',
#      u'thumbnailwidth': u'75'},
#     u'subtype': u'thumbnail',
#     u'type': u'image',
#     u'url': u'images/2011/10/23/nyregion/23MARRIAGE/23MARRIAGE-thumbStandard.jpg',
#     u'width': 75}],
#   u'news_desk': u'Metro',
#   u'print_page': u'4',
#   u'pub_date': u'2011-10-23T00:00:00Z',
#   u'section_name': u'N.Y. / Region',
#   u'snippet': u'State Senator James Alesi, in a panel discussion, said that political considerations had led him to vote \u201cno\u201d two years ago on a bill to legalize same-sex marriage in New York.',
#   u'source': u'The New York Times',
#   u'subsection_name': None,
#   u'type_of_material': u'Text',
#   u'web_url': u'http://www.nytimes.com/2011/10/23/nyregion/why-state-senator-james-alesi-supporter-of-gay-marriage-voted-no-in-09.html',
#   u'word_count': u'576'},
#  {u'_id': u'558db85038f0d8123efd2cc8',
#   u'abstract': u'Republican candidates seem to have no intention of letting this issue go.',
#   u'blog': [],
#   u'byline': {u'original': u'By ANDREW ROSENTHAL',
#    u'person': [{u'firstname': u'Andrew',
#      u'lastname': u'ROSENTHAL',
#      u'organization': u'',
#      u'rank': 1,
#      u'role': u'reported'}]},
#   u'document_type': u'blogpost',
#   u'headline': {u'kicker': u'Taking Note',
#    u'main': u'The Instant Republican Backlash on Gay Marriage'},
#   u'keywords': [{u'name': u'persons', u'rank': u'1', u'value': u'Bush, Jeb'},
#    {u'name': u'persons', u'rank': u'2', u'value': u'Graham, Lindsey'},
#    {u'name': u'persons', u'rank': u'3', u'value': u'Jindal, Bobby'},
#    {u'name': u'persons', u'rank': u'4', u'value': u'Rubio, Marco'},
#    {u'name': u'persons', u'rank': u'5', u'value': u'Walker, Scott K'},
#    {u'name': u'glocations', u'rank': u'1', u'value': u'Florida'},
#    {u'name': u'glocations', u'rank': u'2', u'value': u'Louisiana'},
#    {u'name': u'glocations', u'rank': u'3', u'value': u'United States'},
#    {u'name': u'organizations', u'rank': u'1', u'value': u'Republican Party'},
#    {u'name': u'organizations', u'rank': u'2', u'value': u'Supreme Court (US)'},
#    {u'name': u'subject',
#     u'rank': u'1',
#     u'value': u'Christians and Christianity'},
#    {u'name': u'subject', u'rank': u'2', u'value': u'Constitution (US)'},
#    {u'name': u'subject',
#     u'rank': u'3',
#     u'value': u'Constitutional Amendments'},
#    {u'name': u'subject', u'rank': u'4', u'value': u'Decisions and Verdicts'},
#    {u'name': u'subject', u'rank': u'5', u'value': u'Discrimination'},
#    {u'name': u'subject', u'rank': u'6', u'value': u'Freedom of Religion'},
#    {u'name': u'subject',
#     u'rank': u'7',
#     u'value': u'Homosexuality and Bisexuality'},
#    {u'name': u'subject',
#     u'rank': u'8',
#     u'value': u'Same-Sex Marriage, Civil Unions and Domestic Partnerships'},
#    {u'name': u'subject', u'rank': u'9', u'value': u'States (US)'}],
#   u'lead_paragraph': None,
#   u'multimedia': [{u'height': 126,
#     u'legacy': {u'wide': u'images/2015/06/26/opinion/26rosenthalWEB/26rosenthalWEB-thumbWide.jpg',
#      u'wideheight': u'126',
#      u'widewidth': u'190'},
#     u'subtype': u'wide',
#     u'type': u'image',
#     u'url': u'images/2015/06/26/opinion/26rosenthalWEB/26rosenthalWEB-thumbWide.jpg',
#     u'width': 190},
#    {u'height': 400,
#     u'legacy': {u'xlarge': u'images/2015/06/26/opinion/26rosenthalWEB/26rosenthalWEB-articleLarge.jpg',
#      u'xlargeheight': u'400',
#      u'xlargewidth': u'600'},
#     u'subtype': u'xlarge',
#     u'type': u'image',
#     u'url': u'images/2015/06/26/opinion/26rosenthalWEB/26rosenthalWEB-articleLarge.jpg',
#     u'width': 600},
#    {u'height': 75,
#     u'legacy': {u'thumbnail': u'images/2015/06/26/opinion/26rosenthalWEB/26rosenthalWEB-thumbStandard.jpg',
#      u'thumbnailheight': u'75',
#      u'thumbnailwidth': u'75'},
#     u'subtype': u'thumbnail',
#     u'type': u'image',
#     u'url': u'images/2015/06/26/opinion/26rosenthalWEB/26rosenthalWEB-thumbStandard.jpg',
#     u'width': 75}],
#   u'news_desk': u'OpEd',
#   u'print_page': None,
#   u'pub_date': u'2015-06-26T16:35:20Z',
#   u'section_name': u'false',
#   u'snippet': u'Republican candidates seem to have no intention of letting this issue go.',
#   u'source': u'The New York Times',
#   u'subsection_name': u'false',
#   u'type_of_material': u'Blog',
#   u'web_url': u'http://takingnote.blogs.nytimes.com/2015/06/26/the-instant-republican-backlash-on-gay-marriage/',
#   u'word_count': u'681'},
#  {u'_id': u'5560c88838f0d8256317c117',
#   u'abstract': None,
#   u'blog': [],
#   u'byline': {u'organization': u'Reuters',
#    u'original': u'Reuters',
#    u'person': []},
#   u'document_type': u'multimedia',
#   u'headline': {u'main': u'Ireland Legalizes Gay Marriage'},
#   u'keywords': [{u'is_major': u'N',
#     u'name': u'subject',
#     u'rank': u'1',
#     u'value': u'Homosexuality and Bisexuality'},
#    {u'is_major': u'N',
#     u'name': u'subject',
#     u'rank': u'2',
#     u'value': u'Same-Sex Marriage, Civil Unions and Domestic Partnerships'},
#    {u'is_major': u'N',
#     u'name': u'subject',
#     u'rank': u'3',
#     u'value': u'Marriages'},
#    {u'is_major': u'N',
#     u'name': u'glocations',
#     u'rank': u'4',
#     u'value': u'Ireland'}],
#   u'lead_paragraph': u'Ireland has become the first nation to approve same-sex marriage by a popular vote, sweeping aside opposition from the Roman Catholic Church in a resounding victory for the gay rights movement.',
#   u'multimedia': [{u'height': 126,
#     u'legacy': {u'wide': u'images/2015/05/23/multimedia/ireland-gay-marriage/ireland-gay-marriage-thumbWide.jpg',
#      u'wideheight': u'126',
#      u'widewidth': u'190'},
#     u'subtype': u'wide',
#     u'type': u'image',
#     u'url': u'images/2015/05/23/multimedia/ireland-gay-marriage/ireland-gay-marriage-thumbWide.jpg',
#     u'width': 190},
#    {u'height': 338,
#     u'legacy': {u'xlarge': u'images/2015/05/23/multimedia/ireland-gay-marriage/ireland-gay-marriage-articleLarge.jpg',
#      u'xlargeheight': u'338',
#      u'xlargewidth': u'600'},
#     u'subtype': u'xlarge',
#     u'type': u'image',
#     u'url': u'images/2015/05/23/multimedia/ireland-gay-marriage/ireland-gay-marriage-articleLarge.jpg',
#     u'width': 600},
#    {u'height': 75,
#     u'legacy': {u'thumbnail': u'images/2015/05/23/multimedia/ireland-gay-marriage/ireland-gay-marriage-thumbStandard.jpg',
#      u'thumbnailheight': u'75',
#      u'thumbnailwidth': u'75'},
#     u'subtype': u'thumbnail',
#     u'type': u'image',
#     u'url': u'images/2015/05/23/multimedia/ireland-gay-marriage/ireland-gay-marriage-thumbStandard.jpg',
#     u'width': 75}],
#   u'news_desk': u'World / Europe',
#   u'print_page': None,
#   u'pub_date': u'2015-05-23T14:35:15Z',
#   u'section_name': u'World',
#   u'snippet': u'Ireland has become the first nation to approve same-sex marriage by a popular vote, sweeping aside opposition from the Roman Catholic Church in a resounding victory for the gay rights movement.',
#   u'source': u'The New York Times',
#   u'subsection_name': u'Europe',
#   u'type_of_material': u'Video',
#   u'web_url': u'http://www.nytimes.com/video/world/europe/100000003700992/ireland-leglaizes-gay-marriage.html',
#   u'word_count': u'31'},
#  {u'_id': u'558d8d9138f0d8123efd2c38',
#   u'abstract': u'Editorial applauds Supreme Court decision granting gay couples right to marry; holds affirmation belongs among other landmark, and often contentious, Supreme Court rulings in support of basic human rights and represents rapidly changing opinions among American public.',
#   u'blog': [],
#   u'byline': {u'organization': u'THE EDITORIAL BOARD',
#    u'original': u'By THE EDITORIAL BOARD',
#    u'person': []},
#   u'document_type': u'article',
#   u'headline': {u'content_kicker': u'Editorial',
#    u'kicker': u'Editorial',
#    u'main': u'A Profound Ruling Delivers Justice on Gay Marriage',
#    u'print_headline': u'Marriage Equality in America'},
#   u'keywords': [{u'is_major': u'Y',
#     u'name': u'subject',
#     u'rank': u'1',
#     u'value': u'Editorials'},
#    {u'is_major': u'Y',
#     u'name': u'organizations',
#     u'rank': u'2',
#     u'value': u'Supreme Court (US)'},
#    {u'is_major': u'N',
#     u'name': u'persons',
#     u'rank': u'3',
#     u'value': u'Kennedy, Anthony M'},
#    {u'is_major': u'N',
#     u'name': u'subject',
#     u'rank': u'4',
#     u'value': u'Decisions and Verdicts'},
#    {u'is_major': u'Y',
#     u'name': u'subject',
#     u'rank': u'5',
#     u'value': u'Same-Sex Marriage, Civil Unions and Domestic Partnerships'}],
#   u'lead_paragraph': u'Justice Anthony Kennedy\u2019s opinion follows the arc of history in securing more freedom under the Constitution.',
#   u'multimedia': [{u'height': 126,
#     u'legacy': {u'wide': u'images/2015/06/27/opinion/27sat1/27sat1-thumbWide.jpg',
#      u'wideheight': u'126',
#      u'widewidth': u'190'},
#     u'subtype': u'wide',
#     u'type': u'image',
#     u'url': u'images/2015/06/27/opinion/27sat1/27sat1-thumbWide.jpg',
#     u'width': 190},
#    {u'height': 465,
#     u'legacy': {u'xlarge': u'images/2015/06/27/opinion/27sat1/27sat1-articleLarge.jpg',
#      u'xlargeheight': u'465',
#      u'xlargewidth': u'600'},
#     u'subtype': u'xlarge',
#     u'type': u'image',
#     u'url': u'images/2015/06/27/opinion/27sat1/27sat1-articleLarge.jpg',
#     u'width': 600},
#    {u'height': 75,
#     u'legacy': {u'thumbnail': u'images/2015/06/27/opinion/27sat1/27sat1-thumbStandard.jpg',
#      u'thumbnailheight': u'75',
#      u'thumbnailwidth': u'75'},
#     u'subtype': u'thumbnail',
#     u'type': u'image',
#     u'url': u'images/2015/06/27/opinion/27sat1/27sat1-thumbStandard.jpg',
#     u'width': 75}],
#   u'news_desk': u'Editorial',
#   u'print_page': u'20',
#   u'pub_date': u'2015-06-27T00:00:00Z',
#   u'section_name': u'Opinion',
#   u'snippet': u'Justice Anthony Kennedy\u2019s opinion follows the arc of history in securing more freedom under the Constitution.',
#   u'source': u'The New York Times',
#   u'subsection_name': None,
#   u'type_of_material': u'Editorial',
#   u'web_url': u'http://www.nytimes.com/2015/06/27/opinion/a-profound-ruling-delivers-justice-on-gay-marriage.html',
#   u'word_count': u'1328'},
#  {u'_id': u'5565706638f0d84e3574ebfb',
#   u'abstract': None,
#   u'blog': [],
#   u'byline': [],
#   u'document_type': u'article',
#   u'headline': {u'content_kicker': u'Letter',
#    u'kicker': u'Letter',
#    u'main': u'Ireland\u2019s Yes to Gay Marriage',
#    u'print_headline': u'Ireland\u2019s Gay Marriage Vote'},
#   u'keywords': [{u'is_major': u'N',
#     u'name': u'subject',
#     u'rank': u'1',
#     u'value': u'Same-Sex Marriage, Civil Unions and Domestic Partnerships'},
#    {u'is_major': u'N',
#     u'name': u'glocations',
#     u'rank': u'2',
#     u'value': u'Ireland'}],
#   u'lead_paragraph': u'Daniel J. O&#8217;Donnell, a member of the New York Assembly, writes, &#8220;Thank you, Ireland, for voting for another step toward universal human rights for all.&#8221;',
#   u'multimedia': [],
#   u'news_desk': u'Letters',
#   u'print_page': u'18',
#   u'pub_date': u'2015-05-27T00:00:00Z',
#   u'section_name': u'Opinion',
#   u'snippet': u'Daniel J. O&#8217;Donnell, a member of the New York Assembly, writes, &#8220;Thank you, Ireland, for voting for another step toward universal human rights for all.&#8221;',
#   u'source': u'The New York Times',
#   u'subsection_name': None,
#   u'type_of_material': u'Letter',
#   u'web_url': u'http://www.nytimes.com/2015/05/27/opinion/irelands-yes-to-gay-marriage.html',
#   u'word_count': u'187'},
#  {u'_id': u'558d86d838f0d8123efd2c19',
#   u'abstract': u'Maybe not the best choice.',
#   u'blog': [],
#   u'byline': {u'original': u'By LAWRENCE DOWNES',
#    u'person': [{u'firstname': u'Lawrence',
#      u'lastname': u'DOWNES',
#      u'organization': u'',
#      u'rank': 1,
#      u'role': u'reported'}]},
#   u'document_type': u'blogpost',
#   u'headline': {u'kicker': u'Taking Note',
#    u'main': u'On Gay Marriage, John Roberts Invokes &#8230; the Aztecs?'},
#   u'keywords': [{u'name': u'persons',
#     u'rank': u'1',
#     u'value': u'Gingrich, Newt'},
#    {u'name': u'persons', u'rank': u'2', u'value': u'Limbaugh, Rush'},
#    {u'name': u'persons', u'rank': u'3', u'value': u'Roberts, John G Jr'},
#    {u'name': u'glocations', u'rank': u'1', u'value': u'Latin America'},
#    {u'name': u'organizations',
#     u'rank': u'1',
#     u'value': u'University of Texas at Austin'},
#    {u'name': u'subject', u'rank': u'1', u'value': u'Child Abuse and Neglect'},
#    {u'name': u'subject',
#     u'rank': u'2',
#     u'value': u'Homosexuality and Bisexuality'},
#    {u'name': u'subject',
#     u'rank': u'3',
#     u'value': u'Same-Sex Marriage, Civil Unions and Domestic Partnerships'}],
#   u'lead_paragraph': None,
#   u'multimedia': [{u'height': 126,
#     u'legacy': {u'wide': u'images/2015/06/26/opinion/26downesWEB2/26downesWEB2-thumbWide.jpg',
#      u'wideheight': u'126',
#      u'widewidth': u'190'},
#     u'subtype': u'wide',
#     u'type': u'image',
#     u'url': u'images/2015/06/26/opinion/26downesWEB2/26downesWEB2-thumbWide.jpg',
#     u'width': 190},
#    {u'height': 452,
#     u'legacy': {u'xlarge': u'images/2015/06/26/opinion/26downesWEB2/26downesWEB2-articleLarge.jpg',
#      u'xlargeheight': u'452',
#      u'xlargewidth': u'600'},
#     u'subtype': u'xlarge',
#     u'type': u'image',
#     u'url': u'images/2015/06/26/opinion/26downesWEB2/26downesWEB2-articleLarge.jpg',
#     u'width': 600},
#    {u'height': 75,
#     u'legacy': {u'thumbnail': u'images/2015/06/26/opinion/26downesWEB2/26downesWEB2-thumbStandard.jpg',
#      u'thumbnailheight': u'75',
#      u'thumbnailwidth': u'75'},
#     u'subtype': u'thumbnail',
#     u'type': u'image',
#     u'url': u'images/2015/06/26/opinion/26downesWEB2/26downesWEB2-thumbStandard.jpg',
#     u'width': 75}],
#   u'news_desk': u'OpEd',
#   u'print_page': None,
#   u'pub_date': u'2015-06-26T13:06:44Z',
#   u'section_name': u'false',
#   u'snippet': u'Maybe not the best choice.',
#   u'source': u'The New York Times',
#   u'subsection_name': u'false',
#   u'type_of_material': u'Blog',
#   u'web_url': u'http://takingnote.blogs.nytimes.com/2015/06/26/on-same-sex-marriage-john-roberts-invokes-the-aztecs/',
#   u'word_count': u'348'},
#  {u'_id': u'557c630738f0d85fbd03bf86',
#   u'abstract': None,
#   u'blog': [],
#   u'byline': {u'original': u'By GABRIELA HERMAN',
#    u'person': [{u'firstname': u'Gabriela',
#      u'lastname': u'HERMAN',
#      u'organization': u'',
#      u'rank': 1,
#      u'role': u'reported'}]},
#   u'document_type': u'multimedia',
#   u'headline': {u'kicker': u'Exposures',
#    u'main': u'What Could Gay Marriage Mean for the Kids?'},
#   u'keywords': [{u'is_major': u'N',
#     u'name': u'subject',
#     u'rank': u'1',
#     u'value': u'Same-Sex Marriage, Civil Unions and Domestic Partnerships'},
#    {u'is_major': u'N',
#     u'name': u'subject',
#     u'rank': u'2',
#     u'value': u'Families and Family Life'},
#    {u'is_major': u'N',
#     u'name': u'subject',
#     u'rank': u'3',
#     u'value': u'Children and Childhood'}],
#   u'lead_paragraph': u'When courts consider same-sex unions, they often ask about what life is like for children with gay parents. Here are some answers.',
#   u'multimedia': [{u'height': 126,
#     u'legacy': {u'wide': u'images/2015/06/14/opinion/sunday/exposures-kids-slide-KDAI/exposures-kids-slide-KDAI-thumbWide-v3.jpg',
#      u'wideheight': u'126',
#      u'widewidth': u'190'},
#     u'subtype': u'wide',
#     u'type': u'image',
#     u'url': u'images/2015/06/14/opinion/sunday/exposures-kids-slide-KDAI/exposures-kids-slide-KDAI-thumbWide-v3.jpg',
#     u'width': 190},
#    {u'height': 399,
#     u'legacy': {u'xlarge': u'images/2015/06/14/opinion/sunday/exposures-kids-slide-KDAI/exposures-kids-slide-KDAI-articleLarge-v2.jpg',
#      u'xlargeheight': u'399',
#      u'xlargewidth': u'600'},
#     u'subtype': u'xlarge',
#     u'type': u'image',
#     u'url': u'images/2015/06/14/opinion/sunday/exposures-kids-slide-KDAI/exposures-kids-slide-KDAI-articleLarge-v2.jpg',
#     u'width': 600},
#    {u'height': 75,
#     u'legacy': {u'thumbnail': u'images/2015/06/14/opinion/sunday/exposures-kids-slide-KDAI/exposures-kids-slide-KDAI-thumbStandard-v3.jpg',
#      u'thumbnailheight': u'75',
#      u'thumbnailwidth': u'75'},
#     u'subtype': u'thumbnail',
#     u'type': u'image',
#     u'url': u'images/2015/06/14/opinion/sunday/exposures-kids-slide-KDAI/exposures-kids-slide-KDAI-thumbStandard-v3.jpg',
#     u'width': 75}],
#   u'news_desk': u'Sunday Review',
#   u'print_page': None,
#   u'pub_date': u'2015-06-12T00:00:00Z',
#   u'section_name': u'Sunday Review',
#   u'snippet': u'When courts consider same-sex unions, they often ask about what life is like for children with gay parents. Here are some answers.',
#   u'source': u'The New York Times',
#   u'subsection_name': None,
#   u'type_of_material': u'Interactive Feature',
#   u'web_url': u'http://www.nytimes.com/interactive/2015/06/12/sunday-review/same-sex-households-children.html',
#   u'word_count': None},
#  {u'_id': u'5584485a38f0d873a5d4afd8',
#   u'abstract': u'Former Gov. Jeb Bush of Florida, at a gathering of religious conservatives, said he was not content letting the issue of same-sex marriage fade away, \u201cirrespective of what the courts say\u201d about it.',
#   u'blog': [],
#   u'byline': {u'original': u'By JEREMY PETERS',
#    u'person': [{u'firstname': u'Jeremy',
#      u'lastname': u'PETERS',
#      u'organization': u'',
#      u'rank': 1,
#      u'role': u'reported'}]},
#   u'document_type': u'blogpost',
#   u'headline': {u'kicker': u'First Draft',
#    u'main': u'Jeb Bush Pledges Debate on Gay Marriage After Court Ruling',
#    u'print_headline': u'Bush Pledges to Continue Debate on Gay Marriage'},
#   u'keywords': [{u'name': u'persons', u'rank': u'1', u'value': u'Bush, Jeb'},
#    {u'name': u'glocations', u'rank': u'1', u'value': u'Washington (DC)'},
#    {u'name': u'organizations',
#     u'rank': u'1',
#     u'value': u'Faith and Freedom Coalition'},
#    {u'name': u'organizations', u'rank': u'2', u'value': u'Republican Party'},
#    {u'name': u'organizations', u'rank': u'3', u'value': u'Supreme Court (US)'},
#    {u'name': u'subject',
#     u'rank': u'1',
#     u'value': u'Constitutional Amendments'},
#    {u'name': u'subject',
#     u'rank': u'2',
#     u'value': u'Presidential Election of 2016'},
#    {u'name': u'subject',
#     u'rank': u'3',
#     u'value': u'Same-Sex Marriage, Civil Unions and Domestic Partnerships'}],
#   u'lead_paragraph': None,
#   u'multimedia': [{u'height': 126,
#     u'legacy': {u'wide': u'images/2015/06/19/us/politics/19firstdraft-jeb/19firstdraft-jeb-thumbWide.jpg',
#      u'wideheight': u'126',
#      u'widewidth': u'190'},
#     u'subtype': u'wide',
#     u'type': u'image',
#     u'url': u'images/2015/06/19/us/politics/19firstdraft-jeb/19firstdraft-jeb-thumbWide.jpg',
#     u'width': 190},
#    {u'height': 400,
#     u'legacy': {u'xlarge': u'images/2015/06/19/us/politics/19firstdraft-jeb/19firstdraft-jeb-articleLarge.jpg',
#      u'xlargeheight': u'400',
#      u'xlargewidth': u'600'},
#     u'subtype': u'xlarge',
#     u'type': u'image',
#     u'url': u'images/2015/06/19/us/politics/19firstdraft-jeb/19firstdraft-jeb-articleLarge.jpg',
#     u'width': 600},
#    {u'height': 75,
#     u'legacy': {u'thumbnail': u'images/2015/06/19/us/politics/19firstdraft-jeb/19firstdraft-jeb-thumbStandard.jpg',
#      u'thumbnailheight': u'75',
#      u'thumbnailwidth': u'75'},
#     u'subtype': u'thumbnail',
#     u'type': u'image',
#     u'url': u'images/2015/06/19/us/politics/19firstdraft-jeb/19firstdraft-jeb-thumbStandard.jpg',
#     u'width': 75}],
#   u'news_desk': u'Politics',
#   u'print_page': None,
#   u'pub_date': u'2015-06-19T12:49:38Z',
#   u'section_name': u'false',
#   u'snippet': u'Former Gov. Jeb Bush of Florida, at a gathering of religious conservatives, said he was not content letting the issue of same-sex marriage fade away, \u201cirrespective of what the courts say\u201d about it.',
#   u'source': u'The New York Times',
#   u'subsection_name': u'false',
#   u'type_of_material': u'Blog',
#   u'web_url': u'http://www.nytimes.com/politics/first-draft/2015/06/19/jeb-bush-pledges-fight-on-gay-marriage-after-court-ruling/',
#   u'word_count': u'726'}]

# %%
response = data['response']
response
# Out:
# {u'docs': [{u'_id': u'558d7a8c38f0d8123efd2bf0',
#    u'abstract': u"Op-Ed article by Prof Timothy Stewart-Winter worries that advances made for gay rights, such as ability to serve in military and Supreme Court's affirmation of right to marry, may blind people to struggles of other marginalized groups and civil rights issues; calls on gay community to devote itself to cause of protecting those on margins of society from discrimination.",
#    u'blog': [],
#    u'byline': {u'original': u'By TIMOTHY STEWART-WINTER',
#     u'person': [{u'firstname': u'Timothy',
#       u'lastname': u'STEWART-WINTER',
#       u'organization': u'',
#       u'rank': 1,
#       u'role': u'reported'}]},
#    u'document_type': u'article',
#    u'headline': {u'content_kicker': u'Opinion',
#     u'kicker': u'Opinion',
#     u'main': u'The Price of Gay Marriage',
#     u'print_headline': u'The Price of Gay Marriage'},
#    u'keywords': [{u'is_major': u'Y',
#      u'name': u'subject',
#      u'rank': u'1',
#      u'value': u'Same-Sex Marriage, Civil Unions and Domestic Partnerships'},
#     {u'is_major': u'Y',
#      u'name': u'subject',
#      u'rank': u'2',
#      u'value': u'Discrimination'},
#     {u'is_major': u'Y',
#      u'name': u'organizations',
#      u'rank': u'3',
#      u'value': u'Supreme Court (US)'},
#     {u'is_major': u'N',
#      u'name': u'subject',
#      u'rank': u'4',
#      u'value': u'Civil Rights and Liberties'},
#     {u'is_major': u'N',
#      u'name': u'subject',
#      u'rank': u'5',
#      u'value': u'Homosexuality and Bisexuality'}],
#    u'lead_paragraph': u'Will the victory at the Supreme Court blind us to our history of life in the margins?',
#    u'multimedia': [{u'height': 126,
#      u'legacy': {u'wide': u'images/2015/06/28/opinion/sunday/28GAY/28GAY-thumbWide-v2.jpg',
#       u'wideheight': u'126',
#       u'widewidth': u'190'},
#      u'subtype': u'wide',
#      u'type': u'image',
#      u'url': u'images/2015/06/28/opinion/sunday/28GAY/28GAY-thumbWide-v2.jpg',
#      u'width': 190},
#     {u'height': 840,
#      u'legacy': {u'xlarge': u'images/2015/06/28/opinion/sunday/28GAY/28gay-articleLarge.jpg',
#       u'xlargeheight': u'840',
#       u'xlargewidth': u'600'},
#      u'subtype': u'xlarge',
#      u'type': u'image',
#      u'url': u'images/2015/06/28/opinion/sunday/28GAY/28gay-articleLarge.jpg',
#      u'width': 600},
#     {u'height': 75,
#      u'legacy': {u'thumbnail': u'images/2015/06/28/opinion/sunday/28GAY/28GAY-thumbStandard-v2.jpg',
#       u'thumbnailheight': u'75',
#       u'thumbnailwidth': u'75'},
#      u'subtype': u'thumbnail',
#      u'type': u'image',
#      u'url': u'images/2015/06/28/opinion/sunday/28GAY/28GAY-thumbStandard-v2.jpg',
#      u'width': 75}],
#    u'news_desk': u'OpEd',
#    u'print_page': u'1',
#    u'pub_date': u'2015-06-28T00:00:00Z',
#    u'section_name': u'Opinion',
#    u'snippet': u'Will the victory at the Supreme Court blind us to our history of life in the margins?',
#    u'source': u'The New York Times',
#    u'subsection_name': u'Sunday Review',
#    u'type_of_material': u'Op-Ed',
#    u'web_url': u'http://www.nytimes.com/2015/06/28/opinion/sunday/the-price-of-gay-marriage.html',
#    u'word_count': u'1541'},
#   {u'_id': u'558dd5f438f0d8123efd2d2d',
#    u'abstract': None,
#    u'blog': [],
#    u'byline': {u'original': u'By EMILY BAZELON',
#     u'person': [{u'firstname': u'Emily',
#       u'lastname': u'BAZELON',
#       u'organization': u'',
#       u'rank': 1,
#       u'role': u'reported'}]},
#    u'document_type': u'article',
#    u'headline': {u'main': u'Was This the Right Way to Legalize Gay Marriage?'},
#    u'keywords': [{u'is_major': u'N',
#      u'name': u'subject',
#      u'rank': u'1',
#      u'value': u'Decisions and Verdicts'},
#     {u'is_major': u'N',
#      u'name': u'subject',
#      u'rank': u'2',
#      u'value': u'Same-Sex Marriage, Civil Unions and Domestic Partnerships'},
#     {u'is_major': u'N',
#      u'name': u'organizations',
#      u'rank': u'3',
#      u'value': u'Supreme Court (US)'},
#     {u'is_major': u'N',
#      u'name': u'persons',
#      u'rank': u'4',
#      u'value': u'Kennedy, Anthony M'},
#     {u'is_major': u'N',
#      u'name': u'persons',
#      u'rank': u'5',
#      u'value': u'Roberts, John G Jr'}],
#    u'lead_paragraph': u'The Supreme Court\u2019s dissenters raise a reasonable point about today\u2019s historic decision.',
#    u'multimedia': [{u'height': 126,
#      u'legacy': {u'wide': u'images/2015/06/26/magazine/26mag-scotus-1/26mag-scotus-1-thumbWide.jpg',
#       u'wideheight': u'126',
#       u'widewidth': u'190'},
#      u'subtype': u'wide',
#      u'type': u'image',
#      u'url': u'images/2015/06/26/magazine/26mag-scotus-1/26mag-scotus-1-thumbWide.jpg',
#      u'width': 190},
#     {u'height': 421,
#      u'legacy': {u'xlarge': u'images/2015/06/26/magazine/26mag-scotus-1/26mag-scotus-1-articleLarge.jpg',
#       u'xlargeheight': u'421',
#       u'xlargewidth': u'600'},
#      u'subtype': u'xlarge',
#      u'type': u'image',
#      u'url': u'images/2015/06/26/magazine/26mag-scotus-1/26mag-scotus-1-articleLarge.jpg',
#      u'width': 600},
#     {u'height': 75,
#      u'legacy': {u'thumbnail': u'images/2015/06/26/magazine/26mag-scotus-1/26mag-scotus-1-thumbStandard.jpg',
#       u'thumbnailheight': u'75',
#       u'thumbnailwidth': u'75'},
#      u'subtype': u'thumbnail',
#      u'type': u'image',
#      u'url': u'images/2015/06/26/magazine/26mag-scotus-1/26mag-scotus-1-thumbStandard.jpg',
#      u'width': 75}],
#    u'news_desk': u'Magazine',
#    u'print_page': None,
#    u'pub_date': u'2015-06-26T00:00:00Z',
#    u'section_name': u'Magazine',
#    u'snippet': u'The Supreme Court\u2019s dissenters raise a reasonable point about today\u2019s historic decision.',
#    u'source': u'The New York Times',
#    u'subsection_name': None,
#    u'type_of_material': u'News',
#    u'web_url': u'http://www.nytimes.com/2015/06/26/magazine/was-this-the-right-way-to-legalize-gay-marriage.html',
#    u'word_count': u'1069'},
#   {u'_id': u'5402567e38f0d80cceb1facd',
#    u'abstract': u'Transcript of panel discussion at New York Times in which New York Sen James Alesi describes why he voted in favor of gay marriage in 2001, but against it when legislation first came up in 2009.',
#    u'blog': [],
#    u'byline': [],
#    u'document_type': u'article',
#    u'headline': {u'content_kicker': u'Transcript | Gay Marriage',
#     u'kicker': u'Transcript | Gay Marriage',
#     u'main': u'Why State Senator Alesi, Supporter of Gay Marriage, Voted \u2018No\u2019 in \u201909',
#     u'print_headline': u'Why a Supporter Voted \u2018No\u2019 in \u201909',
#     u'seo': u'Why State Senator James Alesi, Supporter of Gay Marriage, Voted \u2018No\u2019 in \u201909'},
#    u'keywords': [{u'is_major': u'Y',
#      u'name': u'subject',
#      u'rank': u'1',
#      u'value': u'Same-Sex Marriage, Civil Unions and Domestic Partnerships'},
#     {u'is_major': u'N',
#      u'name': u'subject',
#      u'rank': u'2',
#      u'value': u'Politics and Government'},
#     {u'is_major': u'N',
#      u'name': u'glocations',
#      u'rank': u'3',
#      u'value': u'New York City'},
#     {u'is_major': u'Y',
#      u'name': u'persons',
#      u'rank': u'4',
#      u'value': u'Alesi, James S'},
#     {u'is_major': u'Y',
#      u'name': u'glocations',
#      u'rank': u'5',
#      u'value': u'New York State'}],
#    u'lead_paragraph': u'State Senator James Alesi, in a panel discussion, said that political considerations had led him to vote \u201cno\u201d two years ago on a bill to legalize same-sex marriage in New York.',
#    u'multimedia': [{u'height': 75,
#      u'legacy': {u'thumbnail': u'images/2011/10/23/nyregion/23MARRIAGE/23MARRIAGE-thumbStandard.jpg',
#       u'thumbnailheight': u'75',
#       u'thumbnailwidth': u'75'},
#      u'subtype': u'thumbnail',
#      u'type': u'image',
#      u'url': u'images/2011/10/23/nyregion/23MARRIAGE/23MARRIAGE-thumbStandard.jpg',
#      u'width': 75}],
#    u'news_desk': u'Metro',
#    u'print_page': u'4',
#    u'pub_date': u'2011-10-23T00:00:00Z',
#    u'section_name': u'N.Y. / Region',
#    u'snippet': u'State Senator James Alesi, in a panel discussion, said that political considerations had led him to vote \u201cno\u201d two years ago on a bill to legalize same-sex marriage in New York.',
#    u'source': u'The New York Times',
#    u'subsection_name': None,
#    u'type_of_material': u'Text',
#    u'web_url': u'http://www.nytimes.com/2011/10/23/nyregion/why-state-senator-james-alesi-supporter-of-gay-marriage-voted-no-in-09.html',
#    u'word_count': u'576'},
#   {u'_id': u'558db85038f0d8123efd2cc8',
#    u'abstract': u'Republican candidates seem to have no intention of letting this issue go.',
#    u'blog': [],
#    u'byline': {u'original': u'By ANDREW ROSENTHAL',
#     u'person': [{u'firstname': u'Andrew',
#       u'lastname': u'ROSENTHAL',
#       u'organization': u'',
#       u'rank': 1,
#       u'role': u'reported'}]},
#    u'document_type': u'blogpost',
#    u'headline': {u'kicker': u'Taking Note',
#     u'main': u'The Instant Republican Backlash on Gay Marriage'},
#    u'keywords': [{u'name': u'persons', u'rank': u'1', u'value': u'Bush, Jeb'},
#     {u'name': u'persons', u'rank': u'2', u'value': u'Graham, Lindsey'},
#     {u'name': u'persons', u'rank': u'3', u'value': u'Jindal, Bobby'},
#     {u'name': u'persons', u'rank': u'4', u'value': u'Rubio, Marco'},
#     {u'name': u'persons', u'rank': u'5', u'value': u'Walker, Scott K'},
#     {u'name': u'glocations', u'rank': u'1', u'value': u'Florida'},
#     {u'name': u'glocations', u'rank': u'2', u'value': u'Louisiana'},
#     {u'name': u'glocations', u'rank': u'3', u'value': u'United States'},
#     {u'name': u'organizations', u'rank': u'1', u'value': u'Republican Party'},
#     {u'name': u'organizations',
#      u'rank': u'2',
#      u'value': u'Supreme Court (US)'},
#     {u'name': u'subject',
#      u'rank': u'1',
#      u'value': u'Christians and Christianity'},
#     {u'name': u'subject', u'rank': u'2', u'value': u'Constitution (US)'},
#     {u'name': u'subject',
#      u'rank': u'3',
#      u'value': u'Constitutional Amendments'},
#     {u'name': u'subject', u'rank': u'4', u'value': u'Decisions and Verdicts'},
#     {u'name': u'subject', u'rank': u'5', u'value': u'Discrimination'},
#     {u'name': u'subject', u'rank': u'6', u'value': u'Freedom of Religion'},
#     {u'name': u'subject',
#      u'rank': u'7',
#      u'value': u'Homosexuality and Bisexuality'},
#     {u'name': u'subject',
#      u'rank': u'8',
#      u'value': u'Same-Sex Marriage, Civil Unions and Domestic Partnerships'},
#     {u'name': u'subject', u'rank': u'9', u'value': u'States (US)'}],
#    u'lead_paragraph': None,
#    u'multimedia': [{u'height': 126,
#      u'legacy': {u'wide': u'images/2015/06/26/opinion/26rosenthalWEB/26rosenthalWEB-thumbWide.jpg',
#       u'wideheight': u'126',
#       u'widewidth': u'190'},
#      u'subtype': u'wide',
#      u'type': u'image',
#      u'url': u'images/2015/06/26/opinion/26rosenthalWEB/26rosenthalWEB-thumbWide.jpg',
#      u'width': 190},
#     {u'height': 400,
#      u'legacy': {u'xlarge': u'images/2015/06/26/opinion/26rosenthalWEB/26rosenthalWEB-articleLarge.jpg',
#       u'xlargeheight': u'400',
#       u'xlargewidth': u'600'},
#      u'subtype': u'xlarge',
#      u'type': u'image',
#      u'url': u'images/2015/06/26/opinion/26rosenthalWEB/26rosenthalWEB-articleLarge.jpg',
#      u'width': 600},
#     {u'height': 75,
#      u'legacy': {u'thumbnail': u'images/2015/06/26/opinion/26rosenthalWEB/26rosenthalWEB-thumbStandard.jpg',
#       u'thumbnailheight': u'75',
#       u'thumbnailwidth': u'75'},
#      u'subtype': u'thumbnail',
#      u'type': u'image',
#      u'url': u'images/2015/06/26/opinion/26rosenthalWEB/26rosenthalWEB-thumbStandard.jpg',
#      u'width': 75}],
#    u'news_desk': u'OpEd',
#    u'print_page': None,
#    u'pub_date': u'2015-06-26T16:35:20Z',
#    u'section_name': u'false',
#    u'snippet': u'Republican candidates seem to have no intention of letting this issue go.',
#    u'source': u'The New York Times',
#    u'subsection_name': u'false',
#    u'type_of_material': u'Blog',
#    u'web_url': u'http://takingnote.blogs.nytimes.com/2015/06/26/the-instant-republican-backlash-on-gay-marriage/',
#    u'word_count': u'681'},
#   {u'_id': u'5560c88838f0d8256317c117',
#    u'abstract': None,
#    u'blog': [],
#    u'byline': {u'organization': u'Reuters',
#     u'original': u'Reuters',
#     u'person': []},
#    u'document_type': u'multimedia',
#    u'headline': {u'main': u'Ireland Legalizes Gay Marriage'},
#    u'keywords': [{u'is_major': u'N',
#      u'name': u'subject',
#      u'rank': u'1',
#      u'value': u'Homosexuality and Bisexuality'},
#     {u'is_major': u'N',
#      u'name': u'subject',
#      u'rank': u'2',
#      u'value': u'Same-Sex Marriage, Civil Unions and Domestic Partnerships'},
#     {u'is_major': u'N',
#      u'name': u'subject',
#      u'rank': u'3',
#      u'value': u'Marriages'},
#     {u'is_major': u'N',
#      u'name': u'glocations',
#      u'rank': u'4',
#      u'value': u'Ireland'}],
#    u'lead_paragraph': u'Ireland has become the first nation to approve same-sex marriage by a popular vote, sweeping aside opposition from the Roman Catholic Church in a resounding victory for the gay rights movement.',
#    u'multimedia': [{u'height': 126,
#      u'legacy': {u'wide': u'images/2015/05/23/multimedia/ireland-gay-marriage/ireland-gay-marriage-thumbWide.jpg',
#       u'wideheight': u'126',
#       u'widewidth': u'190'},
#      u'subtype': u'wide',
#      u'type': u'image',
#      u'url': u'images/2015/05/23/multimedia/ireland-gay-marriage/ireland-gay-marriage-thumbWide.jpg',
#      u'width': 190},
#     {u'height': 338,
#      u'legacy': {u'xlarge': u'images/2015/05/23/multimedia/ireland-gay-marriage/ireland-gay-marriage-articleLarge.jpg',
#       u'xlargeheight': u'338',
#       u'xlargewidth': u'600'},
#      u'subtype': u'xlarge',
#      u'type': u'image',
#      u'url': u'images/2015/05/23/multimedia/ireland-gay-marriage/ireland-gay-marriage-articleLarge.jpg',
#      u'width': 600},
#     {u'height': 75,
#      u'legacy': {u'thumbnail': u'images/2015/05/23/multimedia/ireland-gay-marriage/ireland-gay-marriage-thumbStandard.jpg',
#       u'thumbnailheight': u'75',
#       u'thumbnailwidth': u'75'},
#      u'subtype': u'thumbnail',
#      u'type': u'image',
#      u'url': u'images/2015/05/23/multimedia/ireland-gay-marriage/ireland-gay-marriage-thumbStandard.jpg',
#      u'width': 75}],
#    u'news_desk': u'World / Europe',
#    u'print_page': None,
#    u'pub_date': u'2015-05-23T14:35:15Z',
#    u'section_name': u'World',
#    u'snippet': u'Ireland has become the first nation to approve same-sex marriage by a popular vote, sweeping aside opposition from the Roman Catholic Church in a resounding victory for the gay rights movement.',
#    u'source': u'The New York Times',
#    u'subsection_name': u'Europe',
#    u'type_of_material': u'Video',
#    u'web_url': u'http://www.nytimes.com/video/world/europe/100000003700992/ireland-leglaizes-gay-marriage.html',
#    u'word_count': u'31'},
#   {u'_id': u'558d8d9138f0d8123efd2c38',
#    u'abstract': u'Editorial applauds Supreme Court decision granting gay couples right to marry; holds affirmation belongs among other landmark, and often contentious, Supreme Court rulings in support of basic human rights and represents rapidly changing opinions among American public.',
#    u'blog': [],
#    u'byline': {u'organization': u'THE EDITORIAL BOARD',
#     u'original': u'By THE EDITORIAL BOARD',
#     u'person': []},
#    u'document_type': u'article',
#    u'headline': {u'content_kicker': u'Editorial',
#     u'kicker': u'Editorial',
#     u'main': u'A Profound Ruling Delivers Justice on Gay Marriage',
#     u'print_headline': u'Marriage Equality in America'},
#    u'keywords': [{u'is_major': u'Y',
#      u'name': u'subject',
#      u'rank': u'1',
#      u'value': u'Editorials'},
#     {u'is_major': u'Y',
#      u'name': u'organizations',
#      u'rank': u'2',
#      u'value': u'Supreme Court (US)'},
#     {u'is_major': u'N',
#      u'name': u'persons',
#      u'rank': u'3',
#      u'value': u'Kennedy, Anthony M'},
#     {u'is_major': u'N',
#      u'name': u'subject',
#      u'rank': u'4',
#      u'value': u'Decisions and Verdicts'},
#     {u'is_major': u'Y',
#      u'name': u'subject',
#      u'rank': u'5',
#      u'value': u'Same-Sex Marriage, Civil Unions and Domestic Partnerships'}],
#    u'lead_paragraph': u'Justice Anthony Kennedy\u2019s opinion follows the arc of history in securing more freedom under the Constitution.',
#    u'multimedia': [{u'height': 126,
#      u'legacy': {u'wide': u'images/2015/06/27/opinion/27sat1/27sat1-thumbWide.jpg',
#       u'wideheight': u'126',
#       u'widewidth': u'190'},
#      u'subtype': u'wide',
#      u'type': u'image',
#      u'url': u'images/2015/06/27/opinion/27sat1/27sat1-thumbWide.jpg',
#      u'width': 190},
#     {u'height': 465,
#      u'legacy': {u'xlarge': u'images/2015/06/27/opinion/27sat1/27sat1-articleLarge.jpg',
#       u'xlargeheight': u'465',
#       u'xlargewidth': u'600'},
#      u'subtype': u'xlarge',
#      u'type': u'image',
#      u'url': u'images/2015/06/27/opinion/27sat1/27sat1-articleLarge.jpg',
#      u'width': 600},
#     {u'height': 75,
#      u'legacy': {u'thumbnail': u'images/2015/06/27/opinion/27sat1/27sat1-thumbStandard.jpg',
#       u'thumbnailheight': u'75',
#       u'thumbnailwidth': u'75'},
#      u'subtype': u'thumbnail',
#      u'type': u'image',
#      u'url': u'images/2015/06/27/opinion/27sat1/27sat1-thumbStandard.jpg',
#      u'width': 75}],
#    u'news_desk': u'Editorial',
#    u'print_page': u'20',
#    u'pub_date': u'2015-06-27T00:00:00Z',
#    u'section_name': u'Opinion',
#    u'snippet': u'Justice Anthony Kennedy\u2019s opinion follows the arc of history in securing more freedom under the Constitution.',
#    u'source': u'The New York Times',
#    u'subsection_name': None,
#    u'type_of_material': u'Editorial',
#    u'web_url': u'http://www.nytimes.com/2015/06/27/opinion/a-profound-ruling-delivers-justice-on-gay-marriage.html',
#    u'word_count': u'1328'},
#   {u'_id': u'5565706638f0d84e3574ebfb',
#    u'abstract': None,
#    u'blog': [],
#    u'byline': [],
#    u'document_type': u'article',
#    u'headline': {u'content_kicker': u'Letter',
#     u'kicker': u'Letter',
#     u'main': u'Ireland\u2019s Yes to Gay Marriage',
#     u'print_headline': u'Ireland\u2019s Gay Marriage Vote'},
#    u'keywords': [{u'is_major': u'N',
#      u'name': u'subject',
#      u'rank': u'1',
#      u'value': u'Same-Sex Marriage, Civil Unions and Domestic Partnerships'},
#     {u'is_major': u'N',
#      u'name': u'glocations',
#      u'rank': u'2',
#      u'value': u'Ireland'}],
#    u'lead_paragraph': u'Daniel J. O&#8217;Donnell, a member of the New York Assembly, writes, &#8220;Thank you, Ireland, for voting for another step toward universal human rights for all.&#8221;',
#    u'multimedia': [],
#    u'news_desk': u'Letters',
#    u'print_page': u'18',
#    u'pub_date': u'2015-05-27T00:00:00Z',
#    u'section_name': u'Opinion',
#    u'snippet': u'Daniel J. O&#8217;Donnell, a member of the New York Assembly, writes, &#8220;Thank you, Ireland, for voting for another step toward universal human rights for all.&#8221;',
#    u'source': u'The New York Times',
#    u'subsection_name': None,
#    u'type_of_material': u'Letter',
#    u'web_url': u'http://www.nytimes.com/2015/05/27/opinion/irelands-yes-to-gay-marriage.html',
#    u'word_count': u'187'},
#   {u'_id': u'558d86d838f0d8123efd2c19',
#    u'abstract': u'Maybe not the best choice.',
#    u'blog': [],
#    u'byline': {u'original': u'By LAWRENCE DOWNES',
#     u'person': [{u'firstname': u'Lawrence',
#       u'lastname': u'DOWNES',
#       u'organization': u'',
#       u'rank': 1,
#       u'role': u'reported'}]},
#    u'document_type': u'blogpost',
#    u'headline': {u'kicker': u'Taking Note',
#     u'main': u'On Gay Marriage, John Roberts Invokes &#8230; the Aztecs?'},
#    u'keywords': [{u'name': u'persons',
#      u'rank': u'1',
#      u'value': u'Gingrich, Newt'},
#     {u'name': u'persons', u'rank': u'2', u'value': u'Limbaugh, Rush'},
#     {u'name': u'persons', u'rank': u'3', u'value': u'Roberts, John G Jr'},
#     {u'name': u'glocations', u'rank': u'1', u'value': u'Latin America'},
#     {u'name': u'organizations',
#      u'rank': u'1',
#      u'value': u'University of Texas at Austin'},
#     {u'name': u'subject', u'rank': u'1', u'value': u'Child Abuse and Neglect'},
#     {u'name': u'subject',
#      u'rank': u'2',
#      u'value': u'Homosexuality and Bisexuality'},
#     {u'name': u'subject',
#      u'rank': u'3',
#      u'value': u'Same-Sex Marriage, Civil Unions and Domestic Partnerships'}],
#    u'lead_paragraph': None,
#    u'multimedia': [{u'height': 126,
#      u'legacy': {u'wide': u'images/2015/06/26/opinion/26downesWEB2/26downesWEB2-thumbWide.jpg',
#       u'wideheight': u'126',
#       u'widewidth': u'190'},
#      u'subtype': u'wide',
#      u'type': u'image',
#      u'url': u'images/2015/06/26/opinion/26downesWEB2/26downesWEB2-thumbWide.jpg',
#      u'width': 190},
#     {u'height': 452,
#      u'legacy': {u'xlarge': u'images/2015/06/26/opinion/26downesWEB2/26downesWEB2-articleLarge.jpg',
#       u'xlargeheight': u'452',
#       u'xlargewidth': u'600'},
#      u'subtype': u'xlarge',
#      u'type': u'image',
#      u'url': u'images/2015/06/26/opinion/26downesWEB2/26downesWEB2-articleLarge.jpg',
#      u'width': 600},
#     {u'height': 75,
#      u'legacy': {u'thumbnail': u'images/2015/06/26/opinion/26downesWEB2/26downesWEB2-thumbStandard.jpg',
#       u'thumbnailheight': u'75',
#       u'thumbnailwidth': u'75'},
#      u'subtype': u'thumbnail',
#      u'type': u'image',
#      u'url': u'images/2015/06/26/opinion/26downesWEB2/26downesWEB2-thumbStandard.jpg',
#      u'width': 75}],
#    u'news_desk': u'OpEd',
#    u'print_page': None,
#    u'pub_date': u'2015-06-26T13:06:44Z',
#    u'section_name': u'false',
#    u'snippet': u'Maybe not the best choice.',
#    u'source': u'The New York Times',
#    u'subsection_name': u'false',
#    u'type_of_material': u'Blog',
#    u'web_url': u'http://takingnote.blogs.nytimes.com/2015/06/26/on-same-sex-marriage-john-roberts-invokes-the-aztecs/',
#    u'word_count': u'348'},
#   {u'_id': u'557c630738f0d85fbd03bf86',
#    u'abstract': None,
#    u'blog': [],
#    u'byline': {u'original': u'By GABRIELA HERMAN',
#     u'person': [{u'firstname': u'Gabriela',
#       u'lastname': u'HERMAN',
#       u'organization': u'',
#       u'rank': 1,
#       u'role': u'reported'}]},
#    u'document_type': u'multimedia',
#    u'headline': {u'kicker': u'Exposures',
#     u'main': u'What Could Gay Marriage Mean for the Kids?'},
#    u'keywords': [{u'is_major': u'N',
#      u'name': u'subject',
#      u'rank': u'1',
#      u'value': u'Same-Sex Marriage, Civil Unions and Domestic Partnerships'},
#     {u'is_major': u'N',
#      u'name': u'subject',
#      u'rank': u'2',
#      u'value': u'Families and Family Life'},
#     {u'is_major': u'N',
#      u'name': u'subject',
#      u'rank': u'3',
#      u'value': u'Children and Childhood'}],
#    u'lead_paragraph': u'When courts consider same-sex unions, they often ask about what life is like for children with gay parents. Here are some answers.',
#    u'multimedia': [{u'height': 126,
#      u'legacy': {u'wide': u'images/2015/06/14/opinion/sunday/exposures-kids-slide-KDAI/exposures-kids-slide-KDAI-thumbWide-v3.jpg',
#       u'wideheight': u'126',
#       u'widewidth': u'190'},
#      u'subtype': u'wide',
#      u'type': u'image',
#      u'url': u'images/2015/06/14/opinion/sunday/exposures-kids-slide-KDAI/exposures-kids-slide-KDAI-thumbWide-v3.jpg',
#      u'width': 190},
#     {u'height': 399,
#      u'legacy': {u'xlarge': u'images/2015/06/14/opinion/sunday/exposures-kids-slide-KDAI/exposures-kids-slide-KDAI-articleLarge-v2.jpg',
#       u'xlargeheight': u'399',
#       u'xlargewidth': u'600'},
#      u'subtype': u'xlarge',
#      u'type': u'image',
#      u'url': u'images/2015/06/14/opinion/sunday/exposures-kids-slide-KDAI/exposures-kids-slide-KDAI-articleLarge-v2.jpg',
#      u'width': 600},
#     {u'height': 75,
#      u'legacy': {u'thumbnail': u'images/2015/06/14/opinion/sunday/exposures-kids-slide-KDAI/exposures-kids-slide-KDAI-thumbStandard-v3.jpg',
#       u'thumbnailheight': u'75',
#       u'thumbnailwidth': u'75'},
#      u'subtype': u'thumbnail',
#      u'type': u'image',
#      u'url': u'images/2015/06/14/opinion/sunday/exposures-kids-slide-KDAI/exposures-kids-slide-KDAI-thumbStandard-v3.jpg',
#      u'width': 75}],
#    u'news_desk': u'Sunday Review',
#    u'print_page': None,
#    u'pub_date': u'2015-06-12T00:00:00Z',
#    u'section_name': u'Sunday Review',
#    u'snippet': u'When courts consider same-sex unions, they often ask about what life is like for children with gay parents. Here are some answers.',
#    u'source': u'The New York Times',
#    u'subsection_name': None,
#    u'type_of_material': u'Interactive Feature',
#    u'web_url': u'http://www.nytimes.com/interactive/2015/06/12/sunday-review/same-sex-households-children.html',
#    u'word_count': None},
#   {u'_id': u'5584485a38f0d873a5d4afd8',
#    u'abstract': u'Former Gov. Jeb Bush of Florida, at a gathering of religious conservatives, said he was not content letting the issue of same-sex marriage fade away, \u201cirrespective of what the courts say\u201d about it.',
#    u'blog': [],
#    u'byline': {u'original': u'By JEREMY PETERS',
#     u'person': [{u'firstname': u'Jeremy',
#       u'lastname': u'PETERS',
#       u'organization': u'',
#       u'rank': 1,
#       u'role': u'reported'}]},
#    u'document_type': u'blogpost',
#    u'headline': {u'kicker': u'First Draft',
#     u'main': u'Jeb Bush Pledges Debate on Gay Marriage After Court Ruling',
#     u'print_headline': u'Bush Pledges to Continue Debate on Gay Marriage'},
#    u'keywords': [{u'name': u'persons', u'rank': u'1', u'value': u'Bush, Jeb'},
#     {u'name': u'glocations', u'rank': u'1', u'value': u'Washington (DC)'},
#     {u'name': u'organizations',
#      u'rank': u'1',
#      u'value': u'Faith and Freedom Coalition'},
#     {u'name': u'organizations', u'rank': u'2', u'value': u'Republican Party'},
#     {u'name': u'organizations',
#      u'rank': u'3',
#      u'value': u'Supreme Court (US)'},
#     {u'name': u'subject',
#      u'rank': u'1',
#      u'value': u'Constitutional Amendments'},
#     {u'name': u'subject',
#      u'rank': u'2',
#      u'value': u'Presidential Election of 2016'},
#     {u'name': u'subject',
#      u'rank': u'3',
#      u'value': u'Same-Sex Marriage, Civil Unions and Domestic Partnerships'}],
#    u'lead_paragraph': None,
#    u'multimedia': [{u'height': 126,
#      u'legacy': {u'wide': u'images/2015/06/19/us/politics/19firstdraft-jeb/19firstdraft-jeb-thumbWide.jpg',
#       u'wideheight': u'126',
#       u'widewidth': u'190'},
#      u'subtype': u'wide',
#      u'type': u'image',
#      u'url': u'images/2015/06/19/us/politics/19firstdraft-jeb/19firstdraft-jeb-thumbWide.jpg',
#      u'width': 190},
#     {u'height': 400,
#      u'legacy': {u'xlarge': u'images/2015/06/19/us/politics/19firstdraft-jeb/19firstdraft-jeb-articleLarge.jpg',
#       u'xlargeheight': u'400',
#       u'xlargewidth': u'600'},
#      u'subtype': u'xlarge',
#      u'type': u'image',
#      u'url': u'images/2015/06/19/us/politics/19firstdraft-jeb/19firstdraft-jeb-articleLarge.jpg',
#      u'width': 600},
#     {u'height': 75,
#      u'legacy': {u'thumbnail': u'images/2015/06/19/us/politics/19firstdraft-jeb/19firstdraft-jeb-thumbStandard.jpg',
#       u'thumbnailheight': u'75',
#       u'thumbnailwidth': u'75'},
#      u'subtype': u'thumbnail',
#      u'type': u'image',
#      u'url': u'images/2015/06/19/us/politics/19firstdraft-jeb/19firstdraft-jeb-thumbStandard.jpg',
#      u'width': 75}],
#    u'news_desk': u'Politics',
#    u'print_page': None,
#    u'pub_date': u'2015-06-19T12:49:38Z',
#    u'section_name': u'false',
#    u'snippet': u'Former Gov. Jeb Bush of Florida, at a gathering of religious conservatives, said he was not content letting the issue of same-sex marriage fade away, \u201cirrespective of what the courts say\u201d about it.',
#    u'source': u'The New York Times',
#    u'subsection_name': u'false',
#    u'type_of_material': u'Blog',
#    u'web_url': u'http://www.nytimes.com/politics/first-draft/2015/06/19/jeb-bush-pledges-fight-on-gay-marriage-after-court-ruling/',
#    u'word_count': u'726'}],
#  u'meta': {u'hits': 6673, u'offset': 0, u'time': 49}}

# %%
docs = response["docs"]
for doc in docs:
    print doc["pub_date"]
# Out:
# 2015-06-28T00:00:00Z
# 2015-06-26T00:00:00Z
# 2011-10-23T00:00:00Z
# 2015-06-26T16:35:20Z
# 2015-05-23T14:35:15Z
# 2015-06-27T00:00:00Z
# 2015-05-27T00:00:00Z
# 2015-06-26T13:06:44Z
# 2015-06-12T00:00:00Z
# 2015-06-19T12:49:38Z

# %%
def gay(start, end):
    if start == "1950" and end == "1959":
        return len(doc["pub_date"])

    
    
print gay(1950, 1959)
# Out:
# None
