# %% [markdown]
# #Do Now 2
#
# ## Reviewing: conditionals, dictionaries, lists
#
# # 1. What two errors can you spot below?

# %% [markdown]
# ``
# n = 2;
# if n < 2:
#     print "Small"
# elif n = 2:
#     print "Medium"
# else: print "Large"
# ``

# %%
n = 2 # no semicolon
if n < 2:
    print "Small"
elif n == 2: # python requires double equal signs for comparisons
    print "Medium"
else: 
    print "Large" # must be in a new row
# Out:
# Medium

# %% [markdown]
# # 2. Given the following code, "11238" is a ______ and 23 is a _________ .

# %%
{"11238": 23, "10011": 47}
# Out:
# {'10011': 47, '11238': 23}

# %% [markdown]
# Given the following code, "11238" is a key and 23 is a value. Because it's a dictionary and a dictionary consists of keys and values.

# %% [markdown]
# # 3. How would you add a 'low' of 54 to the following dictionary?

# %%
weather = {"high": 66, "appearance": "cloudy"}

# %%
weather["low"] = 54 # That's how we can add keys and values to a dictionary
print weather
# Out:
# {'high': 66, 'appearance': 'cloudy', 'low': 54}

# %% [markdown]
# # 4. How can we easily get the total of the list below? How about a count of how many elements are in the list?

# %%
numbers = [1, 2, 3, 4, 5, 6, 7]

# %%
print sum(numbers) # we sum it up
# Out:
# 28

# %%
print len(numbers) # we count the values
# Out:
# 7

# %% [markdown]
# # 5. Print the 3rd element of a list named ``dogs``.

# %%
dogs = ["Wuffi", "Schnuffi", "Max"]
print dogs[2]
# Out:
# Max

# %% [markdown]
# Strings can be indexed with the first character having index 0.
#
# ``
# +---+---+---+---+---+---+
#  | P | y | t | h | o | n |
#  +---+---+---+---+---+---+
#  0   1   2   3   4   5   6
# ``

# %% [markdown]
# #5a. Given the following dictionary, how can we get a list of all three ZIP codes?

# %%
data = {"11238": 23, "10011": 47, "10012": 10}

# %%
print data.keys()
# Out:
# ['11238', '10012', '10011']

# %% [markdown]
# # Write a for loop that prints all three zip codes on seperate lines.

# %%
for zip in data.keys():
    print zip
# Out:
# 11238
# 10012
# 10011

# %% [markdown]
# # Given the following list, add together any numbers greater than 10.

# %%
values = [20, 30, 10, 5, 99]

# %%
total = 0
for value in values:
    if value > 10:
        total = total + 1
print total
# Out:
# 3

# %%
# I don't remember how to count
