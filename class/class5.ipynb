# %%
name = "Vanessa"

# %%
name.rjust?

# %%
name.rjust(20, "*")
# Out:
# '*************Vanessa'

# %%
import csv
file = open("sample.csv")
dogs = list(csv.DictReader(file))

# %%
dogs
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-16cf6e072b4e> in <module>()
# ----> 1 dogs
#
# NameError: name 'dogs' is not defined

# %%
dogs
# Out:
# [{'birth': 'Jan-00',
#   'borough': 'Manhattan',
#   'breed': 'Afghan Hound',
#   'dog_name': 'Buddy',
#   'dominant_color': 'BRINDLE',
#   'gender': 'M',
#   'guard_or_trained': 'No',
#   'secondary_color': 'BLACK',
#   'spayed_or_neutered': 'Yes',
#   'third_color': 'n/a',
#   'zip_code': '10003'},
#  {'birth': 'Jul-00',
#   'borough': 'Manhattan',
#   'breed': 'Afghan Hound',
#   'dog_name': 'Nicole',
#   'dominant_color': 'BLACK',
#   'gender': 'F',
#   'guard_or_trained': 'No',
#   'secondary_color': 'n/a',
#   'spayed_or_neutered': 'Yes',
#   'third_color': 'n/a',
#   'zip_code': '10021'},
#  {'birth': 'Nov-00',
#   'borough': 'Manhattan',
#   'breed': 'Afghan Hound',
#   'dog_name': 'Abby',
#   'dominant_color': 'BLACK',
#   'gender': 'F',
#   'guard_or_trained': 'No',
#   'secondary_color': 'TAN',
#   'spayed_or_neutered': 'Yes',
#   'third_color': 'n/a',
#   'zip_code': '10034'},
#  {'birth': 'Jan-02',
#   'borough': 'Manhattan',
#   'breed': 'Afghan Hound',
#   'dog_name': 'Chloe',
#   'dominant_color': 'WHITE',
#   'gender': 'F',
#   'guard_or_trained': 'No',
#   'secondary_color': 'BLOND',
#   'spayed_or_neutered': 'Yes',
#   'third_color': 'n/a',
#   'zip_code': '10024'},
#  {'birth': 'Oct-02',
#   'borough': 'Manhattan',
#   'breed': 'Afghan Hound',
#   'dog_name': 'Jazzle',
#   'dominant_color': 'BLOND',
#   'gender': 'F',
#   'guard_or_trained': 'No',
#   'secondary_color': 'WHITE',
#   'spayed_or_neutered': 'Yes',
#   'third_color': 'BLACK',
#   'zip_code': '10022'},
#  {'birth': 'Jan-03',
#   'borough': 'Bronx',
#   'breed': 'Afghan Hound',
#   'dog_name': 'Trouble',
#   'dominant_color': 'BLOND',
#   'gender': 'M',
#   'guard_or_trained': 'No',
#   'secondary_color': 'WHITE',
#   'spayed_or_neutered': 'Yes',
#   'third_color': 'BLACK',
#   'zip_code': '10472'},
#  {'birth': 'Jun-03',
#   'borough': 'Manhattan',
#   'breed': 'Afghan Hound',
#   'dog_name': 'Grace',
#   'dominant_color': 'CREAM',
#   'gender': 'F',
#   'guard_or_trained': 'No',
#   'secondary_color': 'n/a',
#   'spayed_or_neutered': 'Yes',
#   'third_color': 'n/a',
#   'zip_code': '10021'},
#  {'birth': 'Oct-04',
#   'borough': 'Manhattan',
#   'breed': 'Afghan Hound',
#   'dog_name': 'Sisu',
#   'dominant_color': 'BLACK',
#   'gender': 'M',
#   'guard_or_trained': 'No',
#   'secondary_color': 'WHITE',
#   'spayed_or_neutered': 'No',
#   'third_color': 'GRAY',
#   'zip_code': '10023'},
#  {'birth': 'Feb-05',
#   'borough': 'Queens',
#   'breed': 'Afghan Hound',
#   'dog_name': 'Jakie',
#   'dominant_color': 'WHITE',
#   'gender': 'M',
#   'guard_or_trained': 'No',
#   'secondary_color': 'n/a',
#   'spayed_or_neutered': 'No',
#   'third_color': 'n/a',
#   'zip_code': '11354'}]

# %%
dogs[0]
# Out:
# {'birth': 'Jan-00',
#  'borough': 'Manhattan',
#  'breed': 'Afghan Hound',
#  'dog_name': 'Buddy',
#  'dominant_color': 'BRINDLE',
#  'gender': 'M',
#  'guard_or_trained': 'No',
#  'secondary_color': 'BLACK',
#  'spayed_or_neutered': 'Yes',
#  'third_color': 'n/a',
#  'zip_code': '10003'}

# %%
# !pwd
# Out:
# /Users/vanessawormer/desktop/lede

# %% [markdown]
# #We are learning Markdown
# ## Hello world again
# ### Hello world again again
# You can make text **bold**
# or *italic* or cross things out. Or use `variables`.
#
# I'm talking about dogs.
#
# I'm talking about `dogs`.

# %% [markdown]
# I'm now going to loop through dogs.

# %%
numbers = [1, 2, 3, 4, 5, 6, 7, 5, 8, 9, 4, 6, 3, 2, 9]

# %%
len(numbers)
# Out:
# 15

# %%
# This is the average
sum(numbers)/len(numbers)
# Out:
# 4

# %%
# NumPy
# How to get different kinds of averages using NumPy?
import numpy as np
np.average(numbers)
# Out:
# 4.9333333333333336

# %%
np.median(numbers)
# Out:
# 5.0

# %%
np.mean(numbers)
# Out:
# 4.9333333333333336

# %%
np.std(numbers)
# Out:
# 2.462158041682585

# %%
np.std?

# %%
np.histogram(numbers)
# Out:
# (array([1, 2, 2, 2, 0, 2, 2, 1, 1, 2]),
#  array([ 1. ,  1.8,  2.6,  3.4,  4.2,  5. ,  5.8,  6.6,  7.4,  8.2,  9. ]))

# %%
# matplotlib
# %matplotlib inline

# %%
import matplotlib.pyplot as plt

# %%
plt.hist(numbers)
# Out:
# (array([ 1.,  2.,  2.,  2.,  0.,  2.,  2.,  1.,  1.,  2.]),
#  array([ 1. ,  1.8,  2.6,  3.4,  4.2,  5. ,  5.8,  6.6,  7.4,  8.2,  9. ]),
#  <a list of 10 Patch objects>)

# %%
import csv
file = open("2.5_month.csv")
quakes = list(csv.DictReader(file))

# %%
len(quakes)
# Out:
# 1346

# %%
quakes[0]
# Out:
# {'depth': '116.4',
#  'dmin': '',
#  'gap': '',
#  'id': 'ak11622703',
#  'latitude': '56.4325',
#  'longitude': '-156.2994',
#  'mag': '3.2',
#  'magType': 'ml',
#  'net': 'ak',
#  'nst': '',
#  'place': '79km NNW of Chirikof Island, Alaska',
#  'rms': '0.65',
#  'time': '2015-06-10T15:33:47.000Z',
#  'type': 'earthquake',
#  'updated': '2015-06-10T15:52:30.305Z'}

# %%
quake = quakes[0]
quake["depth"]
# Out:
# '116.4'

# %%
type(quakes[0]
# Out:
#   File "<ipython-input-35-5ef066a85553>", line 1
#     type(quakes[0]
#                   ^
# SyntaxError: unexpected EOF while parsing

# %%
depths = [float(quake["depth"]) for quake in quakes]

# %%
magnitudes = [float(quake["mag"]) for quake in quakes]

# %%
magnitudes
# Out:
# [3.2,
#  2.55,
#  6.0,
#  3.7,
#  3.7,
#  3.7,
#  4.8,
#  4.7,
#  5.0,
#  2.54,
#  4.9,
#  2.6,
#  2.7,
#  4.7,
#  2.5,
#  5.5,
#  4.7,
#  3.6,
#  2.6,
#  4.2,
#  2.7,
#  2.7,
#  3.4,
#  2.7,
#  3.9,
#  4.9,
#  4.8,
#  4.3,
#  2.6,
#  4.4,
#  2.9,
#  2.5,
#  3.83,
#  5.4,
#  2.5,
#  3.3,
#  2.6,
#  5.0,
#  4.7,
#  4.5,
#  4.3,
#  4.6,
#  4.1,
#  4.0,
#  2.7,
#  4.3,
#  2.7,
#  5.1,
#  4.4,
#  4.7,
#  4.1,
#  2.62,
#  4.9,
#  4.6,
#  2.7,
#  3.4,
#  4.6,
#  4.1,
#  5.2,
#  4.8,
#  5.6,
#  4.7,
#  2.53,
#  3.9,
#  2.7,
#  4.5,
#  2.5,
#  2.8,
#  3.1,
#  2.94,
#  2.5,
#  5.3,
#  2.6,
#  2.8,
#  4.8,
#  4.9,
#  4.1,
#  4.3,
#  4.7,
#  3.9,
#  4.8,
#  4.7,
#  5.1,
#  4.7,
#  4.9,
#  2.74,
#  2.5,
#  4.6,
#  6.1,
#  3.7,
#  4.4,
#  3.4,
#  4.4,
#  4.5,
#  5.0,
#  2.5,
#  3.3,
#  2.7,
#  2.6,
#  3.0,
#  4.7,
#  5.0,
#  3.2,
#  2.7,
#  2.91,
#  4.8,
#  2.6,
#  2.8,
#  4.8,
#  2.6,
#  3.0,
#  3.15,
#  2.7,
#  4.2,
#  2.8,
#  4.5,
#  2.5,
#  4.8,
#  2.7,
#  3.2,
#  4.5,
#  4.5,
#  4.6,
#  4.1,
#  5.0,
#  4.3,
#  4.7,
#  4.5,
#  2.8,
#  5.2,
#  3.0,
#  2.8,
#  2.5,
#  3.1,
#  4.6,
#  2.9,
#  4.8,
#  2.63,
#  4.4,
#  4.6,
#  3.0,
#  4.5,
#  4.9,
#  4.4,
#  3.6,
#  4.1,
#  3.6,
#  3.2,
#  4.8,
#  5.0,
#  3.4,
#  2.9,
#  2.8,
#  3.2,
#  3.0,
#  4.7,
#  4.8,
#  5.0,
#  2.8,
#  4.9,
#  2.5,
#  2.7,
#  2.8,
#  3.0,
#  2.9,
#  2.5,
#  3.4,
#  2.8,
#  4.7,
#  4.7,
#  3.3,
#  5.1,
#  2.8,
#  3.31,
#  4.0,
#  3.18,
#  4.1,
#  2.6,
#  6.0,
#  2.6,
#  5.0,
#  4.2,
#  4.6,
#  4.1,
#  3.0,
#  2.6,
#  2.9,
#  3.6,
#  4.9,
#  3.4,
#  4.4,
#  2.8,
#  3.52,
#  2.82,
#  2.6,
#  4.8,
#  2.5,
#  4.8,
#  5.0,
#  3.0,
#  2.76,
#  4.9,
#  2.5,
#  2.6,
#  2.8,
#  4.4,
#  4.8,
#  4.8,
#  2.9,
#  2.7,
#  2.8,
#  2.96,
#  2.7,
#  3.0,
#  2.9,
#  4.8,
#  3.0,
#  2.8,
#  3.1,
#  2.9,
#  2.8,
#  3.1,
#  3.0,
#  3.1,
#  2.8,
#  3.2,
#  3.0,
#  2.66,
#  2.8,
#  2.71,
#  2.55,
#  4.3,
#  4.8,
#  3.0,
#  5.0,
#  2.8,
#  4.2,
#  4.2,
#  2.7,
#  3.8,
#  3.0,
#  4.0,
#  3.1,
#  2.8,
#  4.1,
#  4.6,
#  2.5,
#  2.5,
#  4.7,
#  2.7,
#  4.7,
#  2.9,
#  4.8,
#  4.9,
#  5.0,
#  3.5,
#  2.66,
#  2.6,
#  2.7,
#  2.6,
#  2.5,
#  3.5,
#  4.8,
#  2.6,
#  3.2,
#  2.6,
#  2.8,
#  3.5,
#  4.8,
#  3.0,
#  2.7,
#  3.5,
#  2.67,
#  4.9,
#  5.0,
#  2.8,
#  4.4,
#  2.8,
#  2.6,
#  4.7,
#  2.6,
#  4.6,
#  3.0,
#  3.5,
#  2.5,
#  4.6,
#  3.46,
#  3.3,
#  2.9,
#  5.3,
#  2.5,
#  2.6,
#  2.5,
#  5.0,
#  2.6,
#  3.7,
#  4.8,
#  2.5,
#  4.4,
#  2.9,
#  2.7,
#  3.3,
#  4.2,
#  3.9,
#  3.1,
#  3.2,
#  3.51,
#  2.6,
#  3.0,
#  5.1,
#  2.5,
#  4.2,
#  4.7,
#  4.8,
#  5.1,
#  2.7,
#  2.5,
#  3.3,
#  2.6,
#  2.5,
#  5.9,
#  3.5,
#  3.6,
#  4.6,
#  2.5,
#  3.1,
#  3.2,
#  4.4,
#  4.9,
#  2.91,
#  2.9,
#  5.0,
#  5.2,
#  2.5,
#  5.0,
#  4.3,
#  2.8,
#  4.7,
#  4.8,
#  5.5,
#  3.0,
#  5.0,
#  2.6,
#  4.6,
#  2.8,
#  2.9,
#  2.7,
#  4.3,
#  5.8,
#  2.5,
#  2.9,
#  3.2,
#  2.9,
#  2.5,
#  4.5,
#  4.1,
#  4.6,
#  3.0,
#  2.9,
#  4.0,
#  4.4,
#  4.3,
#  2.5,
#  3.6,
#  2.6,
#  4.8,
#  4.6,
#  5.1,
#  2.7,
#  4.5,
#  2.6,
#  4.9,
#  4.5,
#  3.17,
#  4.6,
#  3.59,
#  4.4,
#  2.6,
#  4.4,
#  4.7,
#  3.5,
#  4.4,
#  3.07,
#  2.56,
#  5.0,
#  3.4,
#  2.7,
#  4.3,
#  2.8,
#  2.5,
#  2.6,
#  2.8,
#  3.1,
#  2.5,
#  2.9,
#  3.3,
#  4.8,
#  3.1,
#  5.3,
#  4.8,
#  5.4,
#  2.8,
#  6.2,
#  2.9,
#  2.8,
#  2.7,
#  3.1,
#  2.5,
#  4.7,
#  4.8,
#  5.9,
#  5.0,
#  4.6,
#  4.2,
#  2.9,
#  2.6,
#  3.3,
#  3.4,
#  4.6,
#  2.7,
#  3.0,
#  7.8,
#  3.8,
#  2.6,
#  2.5,
#  4.0,
#  5.0,
#  4.5,
#  3.8,
#  2.6,
#  2.7,
#  4.7,
#  5.3,
#  3.7,
#  4.8,
#  2.6,
#  4.9,
#  2.62,
#  4.7,
#  4.2,
#  4.5,
#  4.4,
#  3.4,
#  4.8,
#  2.6,
#  2.5,
#  2.7,
#  2.7,
#  3.1,
#  2.65,
#  4.3,
#  2.5,
#  2.7,
#  4.8,
#  2.5,
#  3.1,
#  2.8,
#  3.4,
#  4.9,
#  4.4,
#  3.9,
#  2.7,
#  2.5,
#  2.9,
#  4.8,
#  3.0,
#  2.87,
#  5.1,
#  2.5,
#  3.8,
#  3.5,
#  2.9,
#  3.2,
#  3.8,
#  2.71,
#  2.85,
#  6.7,
#  2.9,
#  2.68,
#  5.2,
#  4.6,
#  2.6,
#  4.3,
#  4.0,
#  2.5,
#  4.4,
#  4.0,
#  2.6,
#  2.8,
#  4.6,
#  2.7,
#  2.5,
#  2.65,
#  4.2,
#  2.5,
#  3.45,
#  3.26,
#  3.9,
#  4.7,
#  4.5,
#  3.2,
#  3.0,
#  3.2,
#  4.8,
#  2.8,
#  4.5,
#  2.6,
#  2.9,
#  2.8,
#  2.8,
#  4.4,
#  4.2,
#  2.5,
#  4.3,
#  3.0,
#  2.5,
#  3.1,
#  2.9,
#  3.1,
#  2.9,
#  2.93,
#  2.5,
#  4.4,
#  2.7,
#  2.6,
#  4.0,
#  4.9,
#  4.8,
#  4.8,
#  3.2,
#  2.7,
#  3.0,
#  4.4,
#  3.0,
#  2.8,
#  2.8,
#  4.8,
#  2.5,
#  2.59,
#  2.6,
#  3.06,
#  4.6,
#  3.3,
#  2.9,
#  3.17,
#  2.62,
#  4.8,
#  3.59,
#  4.7,
#  4.4,
#  3.34,
#  2.8,
#  2.8,
#  5.4,
#  5.3,
#  3.0,
#  2.5,
#  5.4,
#  2.6,
#  3.7,
#  4.6,
#  2.6,
#  4.8,
#  2.86,
#  4.4,
#  3.0,
#  4.3,
#  4.5,
#  4.6,
#  5.3,
#  5.0,
#  2.5,
#  2.6,
#  3.0,
#  3.0,
#  2.6,
#  2.97,
#  3.0,
#  2.6,
#  4.8,
#  3.8,
#  3.0,
#  2.5,
#  2.7,
#  3.3,
#  5.7,
#  4.34,
#  4.3,
#  3.1,
#  4.8,
#  4.5,
#  4.3,
#  3.2,
#  2.8,
#  2.6,
#  3.1,
#  2.6,
#  4.1,
#  4.6,
#  2.61,
#  4.9,
#  4.1,
#  2.7,
#  4.1,
#  4.7,
#  4.8,
#  4.7,
#  2.5,
#  5.3,
#  2.8,
#  4.0,
#  2.9,
#  3.5,
#  4.5,
#  5.3,
#  3.0,
#  3.8,
#  2.7,
#  3.8,
#  2.7,
#  2.6,
#  3.2,
#  4.3,
#  4.1,
#  4.8,
#  2.7,
#  5.3,
#  3.1,
#  3.4,
#  2.7,
#  4.5,
#  4.7,
#  5.1,
#  2.6,
#  5.3,
#  2.5,
#  4.2,
#  5.5,
#  2.6,
#  2.8,
#  3.4,
#  2.8,
#  2.9,
#  5.2,
#  4.9,
#  3.9,
#  5.2,
#  3.0,
#  2.64,
#  3.4,
#  4.3,
#  5.8,
#  2.7,
#  2.7,
#  4.8,
#  2.89,
#  3.59,
#  2.5,
#  4.5,
#  3.3,
#  6.2,
#  4.7,
#  4.3,
#  4.3,
#  4.3,
#  2.68,
#  4.1,
#  4.6,
#  4.8,
#  4.6,
#  4.1,
#  2.58,
#  4.4,
#  4.0,
#  3.1,
#  2.7,
#  2.9,
#  3.3,
#  2.84,
#  6.3,
#  3.1,
#  3.0,
#  4.9,
#  4.8,
#  3.4,
#  4.8,
#  5.0,
#  2.66,
#  4.5,
#  4.7,
#  2.7,
#  2.6,
#  4.9,
#  4.4,
#  5.9,
#  4.0,
#  2.6,
#  3.09,
#  3.3,
#  2.8,
#  4.8,
#  4.8,
#  2.71,
#  5.1,
#  3.4,
#  4.6,
#  2.8,
#  4.5,
#  3.1,
#  3.5,
#  3.0,
#  4.7,
#  2.8,
#  4.6,
#  2.9,
#  4.7,
#  3.41,
#  2.9,
#  3.9,
#  4.7,
#  2.6,
#  2.9,
#  4.7,
#  4.2,
#  4.9,
#  5.3,
#  5.1,
#  6.8,
#  2.8,
#  3.8,
#  3.6,
#  4.9,
#  4.3,
#  5.1,
#  6.9,
#  2.9,
#  4.5,
#  3.52,
#  5.2,
#  4.9,
#  3.0,
#  4.3,
#  3.83,
#  2.79,
#  4.83,
#  3.3,
#  2.7,
#  4.4,
#  4.8,
#  4.4,
#  2.6,
#  3.0,
#  5.2,
#  5.0,
#  4.2,
#  4.2,
#  4.8,
#  4.7,
#  3.5,
#  4.9,
#  3.2,
#  3.16,
#  3.5,
#  4.2,
#  4.6,
#  2.8,
#  3.4,
#  4.6,
#  3.4,
#  3.27,
#  2.7,
#  4.09,
#  3.7,
#  4.3,
#  2.6,
#  4.9,
#  2.6,
#  2.6,
#  3.2,
#  4.1,
#  2.63,
#  4.6,
#  5.7,
#  2.6,
#  2.8,
#  4.1,
#  4.7,
#  3.2,
#  4.6,
#  4.5,
#  2.67,
#  4.6,
#  2.5,
#  2.6,
#  4.5,
#  2.5,
#  4.2,
#  4.8,
#  4.9,
#  4.6,
#  3.3,
#  2.5,
#  2.7,
#  4.6,
#  3.1,
#  3.1,
#  4.2,
#  3.32,
#  4.4,
#  2.8,
#  2.57,
#  3.28,
#  2.7,
#  2.8,
#  2.75,
#  2.89,
#  4.1,
#  4.6,
#  5.1,
#  3.0,
#  4.5,
#  4.3,
#  2.5,
#  4.5,
#  3.4,
#  4.6,
#  2.6,
#  4.9,
#  6.8,
#  5.0,
#  2.5,
#  2.5,
#  4.5,
#  4.4,
#  5.5,
#  4.8,
#  4.2,
#  4.5,
#  4.2,
#  4.4,
#  4.1,
#  4.2,
#  4.3,
#  3.0,
#  2.9,
#  3.0,
#  4.3,
#  2.6,
#  4.2,
#  3.0,
#  4.4,
#  2.5,
#  3.2,
#  2.9,
#  5.5,
#  3.0,
#  4.3,
#  4.0,
#  6.0,
#  4.2,
#  2.8,
#  2.9,
#  2.5,
#  4.6,
#  2.7,
#  2.8,
#  4.2,
#  2.6,
#  2.8,
#  4.4,
#  2.8,
#  2.98,
#  2.6,
#  2.6,
#  3.82,
#  4.4,
#  4.4,
#  3.0,
#  4.7,
#  2.6,
#  6.7,
#  2.78,
#  4.9,
#  5.8,
#  4.7,
#  3.03,
#  4.2,
#  4.7,
#  4.1,
#  4.9,
#  2.6,
#  5.2,
#  2.59,
#  4.3,
#  3.1,
#  2.6,
#  4.2,
#  2.6,
#  2.61,
#  4.2,
#  2.7,
#  2.87,
#  4.9,
#  4.7,
#  2.7,
#  4.5,
#  3.9,
#  4.6,
#  4.9,
#  2.9,
#  4.7,
#  4.5,
#  3.9,
#  4.0,
#  2.7,
#  3.04,
#  4.4,
#  3.0,
#  2.7,
#  4.4,
#  4.1,
#  3.0,
#  2.54,
#  4.6,
#  5.0,
#  4.4,
#  5.1,
#  2.6,
#  4.2,
#  3.3,
#  2.7,
#  5.7,
#  3.0,
#  4.3,
#  4.3,
#  2.6,
#  3.2,
#  4.5,
#  2.6,
#  4.3,
#  4.2,
#  2.8,
#  4.7,
#  4.1,
#  4.2,
#  2.9,
#  4.1,
#  3.3,
#  4.8,
#  2.8,
#  2.9,
#  2.9,
#  4.9,
#  2.7,
#  4.6,
#  4.5,
#  2.8,
#  5.7,
#  3.9,
#  2.73,
#  4.3,
#  3.5,
#  2.63,
#  4.5,
#  2.6,
#  2.5,
#  2.8,
#  4.6,
#  2.8,
#  3.0,
#  3.4,
#  4.0,
#  4.0,
#  3.16,
#  2.6,
#  3.8,
#  2.9,
#  4.5,
#  2.7,
#  2.56,
#  3.1,
#  4.4,
#  2.8,
#  3.6,
#  2.5,
#  4.5,
#  2.82,
#  3.37,
#  5.4,
#  2.76,
#  3.0,
#  3.33,
#  3.1,
#  2.9,
#  2.6,
#  4.8,
#  3.0,
#  5.2,
#  4.7,
#  3.3,
#  ...]

# %%
np.median(depths)
# Out:
# 26.0

# %%
np.median(magnitudes)
# Out:
# 3.7999999999999998

# %% [markdown]
# # Make a scatterplot
# ### You have: plt (mathplotlib plotting module)
# ### You have: magnitudes
# ### You have: dephts
# ### Your target: Make a scatterplot

# %%
plt.scatter(magnitudes, depths)

# %%
plt.scatter(depths, magnitudes)

# %% [markdown]
# # Do Now Number 5

# %%
murders = { "Albany" : 23, "Kings County" : 10, "Rochester" : 7, "Yonkers" : 9 }

# %%
for county in murders.keys():
    print county, murders[county]
# Out:
#  Yonkers 9
# Albany 23
# Rochester 7
# Kings County 10

# %%
total = 0
for county in murders.keys():
    total = total + murders[county]
print total
# Out:
# 49

# %%
float(murders["Kings County"]) / total * 100
# Out:
# 20.408163265306122
